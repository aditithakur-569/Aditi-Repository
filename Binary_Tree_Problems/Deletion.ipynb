# %%
###Write a program to delete a node in binary tree....[start-end: March 18th]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        self.Next = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
      
        
        while q.qsize() > 1:
            
            temp = q.get()
            
            if temp != None:
                print(temp.data,end=" ")
                if temp.LeftChild:
                    
                    q.put(temp.LeftChild) 

                if temp.RightChild:
                   
                    q.put(temp.RightChild)

            else:
                q.put(None)
                print(end='\n')
                
def Inorder_traversal(root):
    
    if root == None:
        return
    Inorder_traversal(root.LeftChild)
    print(root.data,end = " ")
    Inorder_traversal(root.RightChild)
    
                
def delete_a_node_from_binary_tree(root,GNode):
    
    if root == None:
        return
    
    if root.LeftChild == None and root.RightChild == None:
        if root == GNode:
            root = None
            return None
        else:
            return None
        
        
    q = []
    q.append(root)
    curr_node,last_node = None,None
    key_node = None
    prevL,prevR = None,None
    
    while len(q) > 0:
        
        curr_node = q.pop(0)
        
        if curr_node == GNode:
            key_node = curr_node
            
        if curr_node.LeftChild:
            
            q.append(curr_node.LeftChild)
            prevL = curr_node
            prevR = None
            
        if curr_node.RightChild:
            
            q.append(curr_node.RightChild)
            prevR = curr_node
            prevL = None

    last_node = curr_node
    if key_node:
        key_node.data = last_node.data
        if prevR:
            prevR.RightChild = None
            
        if prevL:
            prevL.LeftChild = None
            
        last_node = None
            
        
root1 = Node(4) 
root1.LeftChild = Node(2)
root1.RightChild = Node(9) 
root1.LeftChild.LeftChild = Node(3)
root1.LeftChild.RightChild = Node(5)
root1.RightChild.LeftChild = Node(19)
root1.RightChild.RightChild = Node(7)
root1.LeftChild.LeftChild.LeftChild = Node(99)
root1.LeftChild.LeftChild.LeftChild.LeftChild = Node(-99)
root1.RightChild.RightChild.RightChild = Node(300)
#level_order_traversal(root1)
#print("\n")  
Inorder_traversal(root1)
print("\n")
delete_a_node_from_binary_tree(root1,root1.LeftChild)  
Inorder_traversal(root1)
# Out:
# -99 99 3 2 5 4 19 9 7 300
#
# 99 3 -99 5 4 19 9 7 300

# %%
###Write a program to delete leaf node in binary tree....[start-end: March 18th]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        self.Next = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
      
        
        while q.qsize() > 1:
            
            temp = q.get()
            
            if temp != None:
                print(temp.data,end=" ")
                if temp.LeftChild:
                    
                    q.put(temp.LeftChild) 

                if temp.RightChild:
                   
                    q.put(temp.RightChild)

            else:
                q.put(None)
                print(end='\n')
                
def Inorder_traversal(root):
    
    if root == None:
        return
    Inorder_traversal(root.LeftChild)
    print(root.data,end = " ")
    Inorder_traversal(root.RightChild)
    
                
def delete_leaf_node_from_binary_tree(root,GNode):
    
    if root == None:
        return
    
    if root.LeftChild == None and root.RightChild == None:
        if root == GNode:
            root = None
            return None
        else:
            return None
            
    q = []
    q.append(root)
    curr_node = None
    prevL,prevR = None,None
    
    while len(q) > 0:
        
        curr_node = q.pop(0)
        
        if ((curr_node == GNode) and (curr_node.LeftChild == None and curr_node.RightChild == None)):
            
            if prevL:
                prevL.LeftChild = None
            if prevR:
                prevR.RightChild = None
        
        if curr_node.LeftChild:
            q.append(curr_node.LeftChild)
            if curr_node.LeftChild.LeftChild == None and curr_node.LeftChild.RightChild == None:
                if curr_node.LeftChild == GNode:
                    prevL = curr_node
                    prevR = None
                    
            
        if curr_node.RightChild:
            q.append(curr_node.RightChild)
            if curr_node.RightChild == GNode:
                if curr_node.RightChild.LeftChild == None and curr_node.RightChild.RightChild == None:
                    prevR = curr_node
                    prevL = None
                    

        

            

    
    
root1 = Node(4) 
root1.LeftChild = Node(2)
root1.RightChild = Node(9) 
root1.LeftChild.LeftChild = Node(3)
root1.LeftChild.RightChild = Node(5)
root1.RightChild.LeftChild = Node(19)
root1.RightChild.RightChild = Node(7)
root1.LeftChild.LeftChild.LeftChild = Node(99)
root1.LeftChild.LeftChild.LeftChild.LeftChild = Node(-99)
root1.RightChild.RightChild.RightChild = Node(300)
level_order_traversal(root1)
print("\n")  
#Inorder_traversal(root1)
#print("\n")
#delete_leaf_node_from_binary_tree(root1,root1.RightChild.RightChild.RightChild)
delete_leaf_node_from_binary_tree(root1,root1.LeftChild.LeftChild.LeftChild.LeftChild)
#Inorder_traversal(root1)
#print("\n")
level_order_traversal(root1)
# Out:
# 4
# 2 9
# 3 5 19 7
# 99 300
# -99
#
# 4
# 2 9
# 3 5 19 7
# 99 300

# %%
##Delete binary tree...[start - end: 18th March]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        self.Next = None
        
def level_order_traversal(root):
    
    if root == None:
        print(None)
        return
    
    else:
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
      
        
        while q.qsize() > 1:
            
            temp = q.get()
            
            if temp != None:
                print(temp.data,end=" ")
                if temp.LeftChild:
                    
                    q.put(temp.LeftChild) 

                if temp.RightChild:
                   
                    q.put(temp.RightChild)

            else:
                q.put(None)
                print(end='\n')
                
def Inorder_traversal(root):
    
    if root == None:
        return
    Inorder_traversal(root.LeftChild)
    print(root.data,end = " ")
    Inorder_traversal(root.RightChild)
    
                
def delete_binary_tree(root):
    
    if root == None:
        return
    
    delete_binary_tree(root.LeftChild)
    delete_binary_tree(root.RightChild)
    print("Node being deleted:",root.data)
    root = None
    return root
 
    

    
root1 = Node(4) 
root1.LeftChild = Node(2)
root1.RightChild = Node(9) 
root1.LeftChild.LeftChild = Node(3)
root1.LeftChild.RightChild = Node(5)
root1.RightChild.LeftChild = Node(19)
root1.RightChild.RightChild = Node(7)
root1.LeftChild.LeftChild.LeftChild = Node(99)
root1.LeftChild.LeftChild.LeftChild.LeftChild = Node(-99)
root1.RightChild.RightChild.RightChild = Node(300)
level_order_traversal(root1)
print("\n")  
#Inorder_traversal(root1)
#print("\n")
x = delete_binary_tree(root1)
print("\n")
level_order_traversal(x)
# Out:
# 4
# 2 9
# 3 5 19 7
# 99 300
# -99
#
# Node being deleted: -99
# Node being deleted: 99
# Node being deleted: 3
# Node being deleted: 5
# Node being deleted: 2
# Node being deleted: 19
# Node being deleted: 300
# Node being deleted: 7
# Node being deleted: 9
# Node being deleted: 4
#
#
# None

# %%
##Remove all nodes which don’t lie in any path with sum>= k.[start-end:March 18th]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        self.Next = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
      
        
        while q.qsize() > 1:
            
            temp = q.get()
            
            if temp != None:
                print(temp.data,end=" ")
                if temp.LeftChild:
                    
                    q.put(temp.LeftChild) 

                if temp.RightChild:
                   
                    q.put(temp.RightChild)

            else:
                q.put(None)
                print(end='\n')
                
def Inorder_traversal(root):
    
    if root == None:
        return
    Inorder_traversal(root.LeftChild)
    print(root.data,end = " ")
    Inorder_traversal(root.RightChild)
    
                
def Remove_All_Nodes_Sum_Greater_Than_K(root,total):
    
    if root == None:
        return None

    node_sum = 0
    Remove_All_Nodes_Sum_Greater_Than_K_utility(root,total,node_sum)
    
    
def Remove_All_Nodes_Sum_Greater_Than_K_utility(root,total,node_sum):
    
    if root == None:
        return None
  
    if root.LeftChild == None and root.RightChild == None:

        if node_sum + root.data >= total:
            return root.data
        else:
            return None

    lSum = Remove_All_Nodes_Sum_Greater_Than_K_utility(root.LeftChild,total,node_sum+root.data)
    if lSum == None:
        root.LeftChild = None
 
    rSum = Remove_All_Nodes_Sum_Greater_Than_K_utility(root.RightChild,total,node_sum+root.data)
    if rSum == None:
        root.RightChild = None
   
    return lSum or rSum 
    

    
root1 = Node(4) 
root1.LeftChild = Node(2)
root1.RightChild = Node(9) 
root1.LeftChild.LeftChild = Node(3)
root1.LeftChild.RightChild = Node(5)
root1.RightChild.LeftChild = Node(19)
root1.RightChild.RightChild = Node(7)
root1.LeftChild.LeftChild.LeftChild = Node(99)
root1.LeftChild.LeftChild.LeftChild.LeftChild = Node(-99)
root1.RightChild.RightChild.RightChild = Node(30)
level_order_traversal(root1)
print("\n")  
#Inorder_traversal(root1)
#print("\n")
Remove_All_Nodes_Sum_Greater_Than_K(root1,50)
level_order_traversal(root1)
# Out:
# 4
# 2 9
# 3 5 19 7
# 99 30
# -99
#
# 4
# 9
# 7
# 30

# %%
##Remove nodes on root to leaf paths of length < K.[start-end:March 18th]

## Same as above.
# Out:
# 4
# 2 9
# 3 5 19 7
# 99 300
# -99
#
# Node being deleted: -99
# Node being deleted: 99
# Node being deleted: 3
# Node being deleted: 5
# Node being deleted: 2
# Node being deleted: 19
# Node being deleted: 300
# Node being deleted: 7
# Node being deleted: 9
# Node being deleted: 4
#
#
# None
