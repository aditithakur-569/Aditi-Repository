# %%
##Started : 26th Jan,2021

# %%
#Print all full nodes in a Binary Tree (Start date: 26th Jan,2021 -- End date: 26th Jan,2021)
##Print the nodes at odd levels of a tree recursively.(Start date: 26th Jan,2021 -- End date: 26th Jan,2021)
##Print the nodes at odd levels of a tree iteratively.(Start date: 26th Jan,2021 -- End date: 26th Jan,2021)

import queue
class Node():
    
    def __init__(self,data):
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
class Binary_Tree():
    
    def __init__(self,root):
        self.root = Node(root)
        
    def insert_node_in_Level(self,root,data):
        
        q = queue.Queue()
        q.put(root)
        
        newnode = Node(data)
        while not q.empty():
           
            temp = q.get()
            if temp.LeftChild == None:
                temp.LeftChild = newnode
                return
            else:
                q.put(temp)
                
            if temp.RightChild == None:
                temp.RightChild = newnode
                return
            else:
                q.put(temp)
                
    def level_order_traversal(self,root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
    def print_all_full_nodes(self,root):
        
        if root == None:
            return
        
        if root.LeftChild and root.RightChild:
            print(root.data,end=" ")
            
        self.print_all_full_nodes(root.LeftChild)
        self.print_all_full_nodes(root.RightChild)
        
    def print_nodes_at_odd_level_recur(self,root):
        
        level = 1
        self.print_nodes_at_odd_level_utility(root,level)
        
    def print_nodes_at_odd_level_utility(self,root,level):
        
        if root== None:
            return
        
        if level % 2 != 0:
            
            print(root.data,end=" ")
            
        self.print_nodes_at_odd_level_utility(root.LeftChild,level + 1)
        self.print_nodes_at_odd_level_utility(root.RightChild,level + 1)
        
        
    def print_nodes_at_odd_level_iter(self,root):
        
        q = queue.Queue()
        q.put(root)
        q.put("N")
        level = 1
        
        while q.qsize() > 1:
            
            temp = q.get()                
            if temp == None:
                return
                
            elif temp != "N":
                
                if temp.LeftChild:
                    q.put(temp.LeftChild)
                if temp.RightChild:
                    q.put(temp.RightChild)
                
                
                if level % 2 != 0:
                    print(temp.data,end = " ")
                    
            else:
                level += 1
                q.put("N")
            
        
        
        
    

                
            
            
            
                
bt = Binary_Tree(6)
bt.insert_node_in_Level(bt.root,4)
bt.insert_node_in_Level(bt.root,9)
bt.insert_node_in_Level(bt.root.LeftChild,42)
bt.insert_node_in_Level(bt.root.LeftChild,102)
bt.insert_node_in_Level(bt.root.RightChild,-1)
bt.insert_node_in_Level(bt.root.RightChild,100)
bt.insert_node_in_Level(bt.root.LeftChild.LeftChild,900)
bt.insert_node_in_Level(bt.root.RightChild.RightChild,78)
bt.insert_node_in_Level(bt.root.RightChild.RightChild,88)
#bt.level_order_traversal(bt.root)
print("\n")
#bt.print_all_full_nodes(bt.root)
bt.print_nodes_at_odd_level(bt.root)
print("\n")
bt.print_nodes_at_odd_level_method_2(bt.root)
# Out:
# 6 42 102 -1 100
#
# 6 42 102 -1 100

# %%
##Check if all leaves are at same level
## Recursive Method 1: (Start date: 26th Jan,2021 -- End date: 26th Jan,2021)
## Recursive Method 2: (Start date: 26th Jan,2021 -- End date: 26th Jan,2021)
## Iterative Method: (Start date: 26th Jan,2021 -- End date: 26th Jan,2021)
import queue
class Node():
    
    def __init__(self,data):
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
class Binary_Tree():
    
    def __init__(self,root):
        self.root = Node(root)
        
    def insert_node_in_Level(self,root,data):
        
        q = queue.Queue()
        q.put(root)
        
        newnode = Node(data)
        while not q.empty():
           
            temp = q.get()
            if temp.LeftChild == None:
                temp.LeftChild = newnode
                return
            else:
                q.put(temp)
                
            if temp.RightChild == None:
                temp.RightChild = newnode
                return
            else:
                q.put(temp)
                


    def check_leaves_nodes_recur1(self,root):
    
        d = {}
        level = 1
        self.check_leaves_nodes_utility(root,d,level)
        if len(d)>1:
            return False
        else:
            return True
    
    def check_leaves_nodes_utility(self,root,d,level):
    
        if root == None:
            return

        if root.LeftChild == None and root.RightChild == None:
                        
            if level in d:
                d[level].append(root.data)
            else:
                d[level] =[root.data]
            print(d)
            return
        
      
        self.check_leaves_nodes_utility(root.LeftChild,d,level+1)
        self.check_leaves_nodes_utility(root.RightChild,d,level+1)
        
        
    def check_leaves_nodes_recur2(self,root):
        
        level = 1
        leaflevel = None
        return (self.check_leaves_nodes_recur2_utility(root,level,leaflevel))

        
    def check_leaves_nodes_recur2_utility(self,root,level,leaflevel=None):
       
            
        if root == None:
            return False
        
        if root.LeftChild == None and root.RightChild == None:
            
            if leaflevel == None:
                leaflevel = level
                return True
            
            else:
                return(level == leaflevel) 
            
        #return (self.check_leaves_nodes_recur2_utility(root.LeftChild,level + 1,leaflevel) and
        #        self.check_leaves_nodes_recur2_utility(root.RightChild,level + 1,leaflevel)
         #      )  
        result_left = self.check_leaves_nodes_recur2_utility(root.LeftChild,level + 1,leaflevel)
        result_right = self.check_leaves_nodes_recur2_utility(root.RightChild,level + 1,leaflevel)
        
        if result_left == True and result_right == True:
            return True
        else:
            return False
        
        
    def check_leaves_nodes_iter(self,root):
        
        q = queue.Queue()
        var = []
        q.put(root)
        q.put("N")
        level = 1
        currentlevel = False
        result = None
        
        while q.qsize() > 1:
            
            temp = q.get()
            
            if temp == None:
                return
            
            elif temp == "N":
                
                level += 1
                q.put("N")
                
            elif temp.LeftChild == None and temp.RightChild == None:
                                
                if currentlevel == False:
                    currentlevel = level
                    result = True
    
                elif (currentlevel != level):
                    result = False
                
                else:
                    result = True
     
            else:
                if temp.LeftChild:
                    q.put(temp.LeftChild)
                
                if temp.RightChild:
                    q.put(temp.RightChild)

                    
        return result

                
                
    
        
        
        
        

        
        
bt = Binary_Tree(6)
bt.insert_node_in_Level(bt.root,4)
bt.insert_node_in_Level(bt.root,9)
bt.insert_node_in_Level(bt.root.LeftChild,42)
bt.insert_node_in_Level(bt.root.LeftChild,102)
bt.insert_node_in_Level(bt.root.RightChild,-1)
bt.insert_node_in_Level(bt.root.RightChild,100)
#bt.insert_node_in_Level(bt.root.LeftChild.LeftChild,900)
#bt.insert_node_in_Level(bt.root.LeftChild.LeftChild,89)
#bt.insert_node_in_Level(bt.root.LeftChild.RightChild,-39)
#bt.insert_node_in_Level(bt.root.LeftChild.RightChild,66)
#bt.insert_node_in_Level(bt.root.RightChild.LeftChild,4)
#bt.insert_node_in_Level(bt.root.RightChild.LeftChild,6)
#bt.insert_node_in_Level(bt.root.RightChild.RightChild,78)
#bt.insert_node_in_Level(bt.root.RightChild.RightChild,88)
#x=bt.check_leaves_nodes_recur2(bt.root)

x = bt.check_leaves_nodes_iter(bt.root)
print("x:",x)
if x==True:
    print("All nodes are at the same level...")
elif x == False:
    print("All nodes are not at the same level...")
# Out:
# x: True
# All nodes are at the same level...

# %%
d = {}
d[1]=["a","b","c"]
d[2]=["aa","bb","cc"]
print(len(d))
print(d)
# Out:
# 2
# {1: ['a', 'b', 'c'], 2: ['aa', 'bb', 'cc']}
