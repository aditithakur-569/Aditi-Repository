# %%
##Start date: 17th Feb, 2021

# %%
##Given a binary tree (not a binary search tree) and two values say n1 and n2, write a program to find the
##least common ancestor.
## Method 1 [started-end: 17thFeb]
## Method 2(Parent Pointer, a little difficult to understand but quite interesting)[started-end: 17thFeb]
import queue
class Node:
    def __init__(self,data):
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        self.Parent = None
        
def level_order_traversal(root):
    
    if root == None:
        return 
    q = []
    q.append(root)
    q.append(None)
    while len(q) > 1:
        
        temp = q.pop(0)
        if temp != None:
            print(temp.data,end=" ")
            if temp.LeftChild:
                q.append(temp.LeftChild)
            if temp.RightChild:
                q.append(temp.RightChild)
                
        elif temp == None:
            print(end="\n")
            q.append(None)
            
def least_common_ancestor_method1(root,n1,n2):
    
    if root == None:
        return None
    print("root:",root.data)
    if root.data == n1:
        print("I am here...N1.",root.data)
        return root.data
    elif root.data == n2:
        print("I am here....N2",root.data)
        return root.data
   
    else:
        l = least_common_ancestor_method1(root.LeftChild,n1,n2)
        r = least_common_ancestor_method1(root.RightChild,n1,n2)
        print("root:",root.data,"l:",l,"r:",r)
        if l and r :
            return root.data
        if l != None:return l
        if r != None:return r
        
        
def assign_parent(root):
    
    if root == None:
        return
    if root.LeftChild:
        root.LeftChild.Parent = root
    if root.RightChild:
        root.RightChild.Parent = root

    assign_parent(root.LeftChild)
    assign_parent(root.RightChild)
    

def least_common_ancestor_method2(root,n1,n2):
    
    if root == None:
        return None
    
    assign_parent(root)
    
    p1 = n1
    p2 = n2
    while p1 != p2:
        
        p1 = p1.Parent
        p2 = p2.Parent

        if p1 == None and p2 == None:
            print("Nodes",n1,"and",n2,"are not of the same tree...")
            return None

        if p1== None:
            p1 = n1

        elif p2 == None:
            p2 = n2

    return p1.data
       
  
    
 

        
            
root = Node(14) 
root.LeftChild = Node(8) 
root.RightChild = Node(6) 
root.LeftChild.LeftChild = Node(3) 
#root.LeftChild.RightChild = Node(86)
root.LeftChild.LeftChild.LeftChild = Node(2)
#root.LeftChild.LeftChild.RightChild = Node(-10)
#root.LeftChild.RightChild.RightChild = Node(72)
root.RightChild.LeftChild = Node(21)
root.RightChild.RightChild = Node(4)
#root.RightChild.RightChild.RightChild = Node(9)
#root.RightChild.RightChild.RightChild.RightChild = Node(0)                                  
level_order_traversal(root)
print("\n")
least_common_ancestor_method1(root,2,4)
#least_common_ancestor_method2(root,root.RightChild.RightChild,root.RightChild.RightChild.RightChild.RightChild)
#least_common_ancestor_method2(root,root.RightChild.LeftChild,root.RightChild.RightChild.RightChild.RightChild)
# Out:
# 14
# 8 6
# 3 21 4
# 2
#
# root: 14
# root: 8
# root: 3
# root: 2
# I am here...N1. 2
# root: 3 l: 2 r: None
# root: 8 l: 2 r: None
# root: 6
# root: 21
# root: 21 l: None r: None
# root: 4
# I am here....N2 4
# root: 6 l: None r: 4
# root: 14 l: 2 r: 4
# 14

# %%
##Find distance between two nodes of a Binary Tree.[started: 17thFeb, end: 18thFeb] ***HARD***

import queue
class Node:
    def __init__(self,data):
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        self.Parent = None
        
def level_order_traversal(root):
    
    if root == None:
        return 
    q = []
    q.append(root)
    q.append(None)
    while len(q) > 1:
        
        temp = q.pop(0)
        if temp != None:
            print(temp.data,end=" ")
            if temp.LeftChild:
                q.append(temp.LeftChild)
            if temp.RightChild:
                q.append(temp.RightChild)
                
        elif temp == None:
            print(end="\n")
            q.append(None)
            
def dist_between_two_nodes(root,n1,n2):
    
    if root == None:
        return -1
    LCA = find_LCA(root,n1,n2)
    dist1,dist2 = [],[]
    level = 0
    cal_root_to_node_distane(LCA,n1,dist1,level)
    cal_root_to_node_distane(LCA,n2,dist2,level)
    return dist1[0] + dist2[0]


def find_LCA(root,n1,n2):
    
    if root == None:
        return None
    
    if root.data == n1 or root.data == n2:
        return root
    
    l = find_LCA(root.LeftChild,n1,n2)
    r = find_LCA(root.RightChild,n1,n2)
    if l and r:
        return root
    if l != None:
        return l
    if r != None:
        return r

    
    
def cal_root_to_node_distane(root,N,dist,level):
    
    
    if root == None:
        return

    if root.data == N:
        dist.append(level)
        return
 
    cal_root_to_node_distane(root.LeftChild,N,dist,level+1)
    cal_root_to_node_distane(root.RightChild,N,dist,level+1)

    
root = Node(14) 
root.LeftChild = Node(8) 
root.RightChild = Node(6) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(86)
root.LeftChild.LeftChild.LeftChild = Node(2)
root.LeftChild.LeftChild.RightChild = Node(-10)
root.LeftChild.RightChild.RightChild = Node(72)
root.RightChild.LeftChild = Node(21)
root.RightChild.RightChild = Node(4)
root.RightChild.RightChild.RightChild = Node(9)
root.RightChild.RightChild.RightChild.RightChild = Node(0)                                  
level_order_traversal(root)
print("\n")
dist_between_two_nodes(root,2,0)
# Out:
# 14
# 8 6
# 3 86 21 4
# 2 -10 72 9
# 0
# 7

# %%
###print-path-between-any-two-nodes-in-a-binary-tree[start-end: 18th Feb]
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
                
def print_path_between_two_nodes(root,n1,n2):
    
    LCA = find_LCA(root,n1,n2)
    
    l1,l2 = [],[]
    print_path(LCA,n1,l1)
    print_path(LCA,n2,l2)
    l2.pop(-1)
    
    for i in l1:
        print(i,end="-->")
    for j in reversed(l2):
        print(j,end="-->")


def find_LCA(root,n1,n2):
    
    if root == None:
        return None
    
    if root.data == n1 or root.data == n2:
        return root
    
    l = find_LCA(root.LeftChild,n1,n2)
    r = find_LCA(root.RightChild,n1,n2)
    if l and r:
        return root
    if l != None:
        return l
    if r != None:
        return r
        
def print_path(LCA,n,temp):
    
    if LCA == None:
        return
    if LCA.data == n:
        temp.append(LCA.data)
        return temp
    else:
        
        l = print_path(LCA.LeftChild,n,temp)
        if l != None:
            temp.append(LCA.data)
            return temp
            
        r = print_path(LCA.RightChild,n,temp)
        if r != None:
            temp.append(LCA.data)
            return temp


        

    
    

    
    


root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(7) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.LeftChild.LeftChild = Node(90)
root.LeftChild.LeftChild.RightChild = Node(78)
root.RightChild.LeftChild = Node(9)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(66)
root.RightChild.RightChild.RightChild.RightChild = Node(-66)
level_order_traversal(root)
print("\n")
print_path_between_two_nodes(root,90,18)

# %%
#Find ancestors of given node in a Binary Tree.(recur)-[start-end: 18th Feb]
#Find ancestors of given node in a Binary Tree.(iter)-[start: 18th Feb--do it later]
import queue
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def print_ancestors_of_given_node_recur(root,N):
    
    if root == None:
        return None
    
    if root.data == N:
        return 0
    
    l = print_ancestors_of_given_node(root.LeftChild,N)
    if l != None:
        print(root.data,end="-->")
        return 0
    r = print_ancestors_of_given_node(root.RightChild,N)
    if r != None:
        print(root.data,end="-->")
        return 0
    
def print_ancestors_of_given_node_iter(root,N):
    
    if root == None:
        return None
    if root.data == N:
        return None
    q1,q2 = [],[]
    q1.append(root)
    q1.append(root)
    while q:
        
        temp = q1[-1]
    
            


    
    
root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(7) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.LeftChild.LeftChild = Node(90)
root.LeftChild.LeftChild.RightChild = Node(78)
root.RightChild.LeftChild = Node(9)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(66)
root.RightChild.RightChild.RightChild.RightChild = Node(-66)
level_order_traversal(root)
print("\n")    
print_ancestors_of_given_node(root,66)
# Out:
# 14
# 2 7
# 3 18 9 -1
# 90 78 6 66
# -66
#
# -1-->7-->14-->
# 0

# %%
#Given a binary tree and two nodes,print all the nodes that are common for 2 given nodes in a binary tree.Print
##common nodes on path from root (or common ancestors).[start-end:19th Feb]

import queue
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def print_common_nodes(root,N1,N2):
    
    if root == None:
        return None
    
    temp1 = deque()
    temp2 = deque()
    find_path_from_root(root,N1,temp1)
    find_path_from_root(root,N2,temp2)
    print(temp1,temp2)
    for i in temp1:
        if i in temp2:
            print(i,end=" ")
    
def find_path_from_root(root,N,temp):
    
    if root == None:
        return None
    
    if root.data == N:
        temp.appendleft(root.data)
        return root.data
    
    l = find_path_from_root(root.LeftChild,N,temp)
    if l != None:
        temp.appendleft(root.data)
        return l
    r = find_path_from_root(root.RightChild,N,temp)
    if r != None:
        temp.appendleft(root.data)
        return r
    
root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(7) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.LeftChild.LeftChild = Node(90)
root.LeftChild.LeftChild.RightChild = Node(78)
root.RightChild.LeftChild = Node(9)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(66)
root.RightChild.RightChild.RightChild.RightChild = Node(-66)
level_order_traversal(root)
print("\n")
print_common_nodes(root,90,78)
# Out:
# 14
# 2 7
# 3 18 9 -1
# 90 78 6 66
# -66
#
# deque([14, 2, 3, 90]) deque([14, 2, 3, 78])
# 14 2 3

# %%
##Print path from root to a given node in a binary tree.[start-end:19th Feb]
import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def print_path_from_root_to_node(root,N):
    temp= deque()
    if root == N:
        return root.data
    else:
        find_path_from_root(root,N,temp)
        for i in temp:
            print(i,end= " ")
        
        

   
    

                
    
root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(7) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.LeftChild.LeftChild = Node(90)
root.LeftChild.LeftChild.RightChild = Node(78)
root.RightChild.LeftChild = Node(9)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(66)
root.RightChild.RightChild.RightChild.RightChild = Node(-66)
level_order_traversal(root)
print("\n")    
print_path_from_root_to_node(root,-66)
# Out:
# 14
# 2 7
# 3 18 9 -1
# 90 78 6 66
# -66
#
# 14 7 -1 66 -66

# %%
#Maximum difference between node and its ancestor in Binary Tree.[start:19th Feb,end:20th Feb]
##Given a binary tree, we need to find maximum value we can get by subtracting value of node B from value of 
##node A, where A and B are two nodes of the binary tree and A is an ancestor of B. 
##Expected time complexity is O(n).(Looked at the solution from internet..Extremely hard to understand)

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def find_max_difference(root):
    
    if root == None:
        return None
    
    _Maxdiff = 11111111111
    min_diff = -11111111111
    diff = min_diff
    x = calculate_max_difference(root,_Maxdiff,diff)
    print(x)
   
    
def calculate_max_difference(root,_Maxdiff,diff):
     
    if (root == None):
        return _Maxdiff,diff 

        
    if (root.LeftChild == None and root.RightChild == None): 
        return root.data,diff 

    a,diff = calculate_max_difference(root.LeftChild,_Maxdiff,diff)
    print("a:",a,"diff:",diff)
    b,diff = calculate_max_difference(root.RightChild,_Maxdiff,diff)
    print("b:",b,"diff:",diff)
    val = min(a, b)
    diff = max(diff, root.data - val)
    print("root:",root.data,"val:",val,"diff:",diff)

    return min(val, root.data), diff
        
 
        
    
        


    
                
                
root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(7) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.LeftChild.LeftChild = Node(90)
root.LeftChild.LeftChild.RightChild = Node(78)
root.RightChild.LeftChild = Node(9)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(66)
root.RightChild.RightChild.RightChild.RightChild = Node(66)
level_order_traversal(root)
print("\n")    
find_max_difference(root)
# Out:
# 14
# 2 7
# 3 18 9 -1
# 90 78 6 66
# 66
#
# a: 90 diff: -11111111111
# b: 78 diff: -11111111111
# root: 3 val: 78 diff: -75
# a: 3 diff: -75
# b: 18 diff: -75
# root: 2 val: 3 diff: -1
# a: 2 diff: -1
# a: 9 diff: -1
# a: 6 diff: -1
# a: 11111111111 diff: -1
# b: 66 diff: -1
# root: 66 val: 66 diff: 0
# b: 66 diff: 0
# root: -1 val: 6 diff: 0
# b: -1 diff: 0
# root: 7 val: -1 diff: 8
# b: -1 diff: 8
# root: 14 val: -1 diff: 15
# (-1, 15)

# %%
# Out:
# 14
# 2 10
# 3 18 4 -1
# 11 8 6 4
#
# root: 2 var: 12
# root: 2 mydict: [2]
# root: 3 var: 11
# root: 3 mydict: [2, 3]
# root: 11 var: 3
# I am here...
# root: 3 resL True
# root: 8 var: 6
# root: 8 mydict: [2, 3, 8]
# root: 8 resL False
# root: 8 resR False
# **root**: 8 mydict: [2, 3]
# root: 3 resR False
# **root**: 3 mydict: [2]
# root: 2 resL True
# root: 18 var: -4
# root: 18 mydict: [2, 18]
# root: 18 resL False
# root: 18 resR False
# **root**: 18 mydict: [2]
# root: 2 resR False
# **root**: 2 mydict: []
# root: 10 var: 4
# root: 10 mydict: [10]
# root: 4 var: 10
# I am here...
# root: 10 resL True
# root: -1 var: 15
# root: -1 mydict: [10, -1]
# root: 6 var: 8
# root: 6 mydict: [10, -1, 6]
# root: 6 resL False
# root: 6 resR False
# **root**: 6 mydict: [10, -1]
# root: -1 resL False
# root: 4 var: 10
# I am here...
# root: -1 resR True
# **root**: -1 mydict: [10]
# root: 10 resR True
# **root**: 10 mydict: []
# True

# %%
a = True
b = False
print(a or b)
# Out:
# True
