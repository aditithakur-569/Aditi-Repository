# %%
## Started: 26th Jan,2021
## Ended: March 2nd, 2021

# %%
###Give an algorithm for finding the sum of all elements in a binary tree.
## Recursive Approach - (Start date: 26th Jan,2021 -- End date: 27th Jan,2021)
## Iterative Approach - (Start date: 27th Jan,2021 -- End date: 27th Jan,2021)
##Sum of all the parent nodes having child node x(recur)(Start date: 27th Jan,2021 -- End date: 27th Jan,2021)
#Sum of all the parent nodes having child node x(iter)(Start date: 27th Jan,2021 -- End date: 27th Jan,2021)
import queue
class Node():
    
    def __init__(self,data):
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
class Binary_Tree():
    
    def __init__(self,root):
        self.root = Node(root)
        
    def insert_node_in_Level(self,root,data):
        
        q = queue.Queue()
        q.put(root)
        
        newnode = Node(data)
        while not q.empty():
           
            temp = q.get()
            if temp.LeftChild == None:
                temp.LeftChild = newnode
                return
            else:
                q.put(temp)
                
            if temp.RightChild == None:
                temp.RightChild = newnode
                return
            else:
                q.put(temp)
                
    def level_order_traversal(self,root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
    def cal_sum_of_all_nodes_recur(self,root,total = 0):
        
        if root == None:
            return 
 
        left_sum = self.cal_sum_of_all_nodes_recur(root.LeftChild)
        right_sum = self.cal_sum_of_all_nodes_recur(root.RightChild)
        
        if left_sum != None:
            total = total + left_sum
        if right_sum != None:
            total = total + right_sum
        return (total + root.data)
        
    def cal_sum_of_all_nodes_iter(self,root):
        
        q= queue.Queue()
        q.put(root)
        total = 0
        while q.qsize() >0:
            
            temp = q.get()
            total = total + temp.data
            if temp.LeftChild:
                q.put(temp.LeftChild)
            if temp.RightChild:
                q.put(temp.RightChild)
        return total
            
 

    def sum_of_parent_nodes_iter(self,root,x):
        
        q = queue.Queue()
        q.put(root)
        total = 0
        
        while q.qsize() > 0:
            
            temp = q.get()
            
            if temp.LeftChild:
                q.put(temp.LeftChild)
            if temp.RightChild:
                q.put(temp.RightChild)
            
           # if temp.LeftChild != None and temp.RightChild != None:
                
            #    if temp.LeftChild.data == x or temp.RightChild.data == x:
            #        total = total + temp.data 
            if ((temp.LeftChild != None and temp.LeftChild.data == x) or 
             (temp.RightChild != None and temp.RightChild.data == x)):
                total = total + temp.data
            
            
        return total
    
    def sum_of_parent_nodes_recur(self,root,x):
        
        total = [0]
        print(type(total))
        self.sum_of_parent_nodes_util(root,total,x)
        return total
        
        
    def sum_of_parent_nodes_util(self,root,total,x):
        
       
        if root == None:
            return
        
        
        if ((root.LeftChild != None and root.LeftChild.data == x) or 
             (root.RightChild != None and root.RightChild.data == x)):
                total[0] = total[0] + root.data
               
        self.sum_of_parent_nodes_util(root.LeftChild,total,x)
        self.sum_of_parent_nodes_util(root.RightChild,total,x)
    
        
        
        
                
            
    
           
            
bt = Binary_Tree(6)
bt.insert_node_in_Level(bt.root,4)
bt.insert_node_in_Level(bt.root,9)
bt.insert_node_in_Level(bt.root.LeftChild,4)
bt.insert_node_in_Level(bt.root.LeftChild,102)
bt.insert_node_in_Level(bt.root.RightChild,-1)
bt.insert_node_in_Level(bt.root.RightChild,100)
bt.insert_node_in_Level(bt.root.LeftChild.LeftChild,900)
bt.insert_node_in_Level(bt.root.RightChild.RightChild,4)
bt.insert_node_in_Level(bt.root.RightChild.RightChild,88)
bt.level_order_traversal(bt.root)
print("\n")
#bt.cal_sum_of_all_nodes_recur(bt.root)
#bt.cal_sum_of_all_nodes_iter(bt.root)
bt.sum_of_parent_nodes_iter(bt.root,4)
#bt.sum_of_parent_nodes_recur(bt.root,4)
# Out:
# 6
# 4 9
# 4 102 -1 100
# 900 4 88
# 110

# %%
## Find sum of all left leaves in a binary tree(recur) - -(Start -End date: 27th Jan,2021)
## Find sum of all left leaves in a binary tree(iter) - -(Start -End date: 27th Jan,2021)
## Find sum of all right leaves in a binary tree(recur) - -(Start -End date: 27th Jan,2021)
## Find sum of all right leaves in a binary tree(iter) - -(Start -End date: 27th Jan,2021)
import queue
class Node():
    
    def __init__(self,data):
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
class Binary_Tree():
    
    def __init__(self,root):
        self.root = Node(root)
        
    def insert_node_in_Level(self,root,data):
        
        q = queue.Queue()
        q.put(root)
        
        newnode = Node(data)
        while not q.empty():
           
            temp = q.get()
            if temp.LeftChild == None:
                temp.LeftChild = newnode
                return
            else:
                q.put(temp)
                
            if temp.RightChild == None:
                temp.RightChild = newnode
                return
            else:
                q.put(temp)
                
    def level_order_traversal(self,root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
    def sum_of_left_leaf_nodes_recur(self,root):
        
        isLeft = False
        total = [0]
        self.sum_of_left_leaf_nodes_recur_util(root,isLeft,total)
        return total
        
    def sum_of_left_leaf_nodes_recur_util(self,root,isLeft,total):
        
        if root == None:
            return
            
        if isLeft == True:
            if root.LeftChild == None and root.RightChild == None:
                total[0] += root.data
                print("root:",root.data)
                
        self.sum_of_left_leaf_nodes_recur_util(root.LeftChild,True,total)
        self.sum_of_left_leaf_nodes_recur_util(root.RightChild,False,total)
        
    def sum_of_left_leaf_nodes_iter(self,root):
        #Stack
        s = []
        var = []
        s.append(root)
        total = 0
        
        while len(s) > 0:
            
            temp = s.pop(0)
            
            if temp.LeftChild:
                s.append(temp.LeftChild)
                
                if temp.LeftChild.LeftChild == None and temp.LeftChild.RightChild == None:
                    total = total + temp.LeftChild.data       

            if temp.RightChild:
                s.append(temp.RightChild)
            
        return total
    
    
    def sum_of_right_leaf_nodes_recur(self,root):
        
        isRight = False
        total = [0]
        self.sum_of_right_leaf_nodes_recur_util(root,isRight,total)
        return total
        
    def sum_of_right_leaf_nodes_recur_util(self,root,isRight,total):
        
        if root == None:
            return
            
        if isRight == True:
            if root.LeftChild == None and root.RightChild == None:
                total[0] += root.data
                print("root:",root.data)
                
        self.sum_of_right_leaf_nodes_recur_util(root.LeftChild,False,total)
        self.sum_of_right_leaf_nodes_recur_util(root.RightChild,True,total)
        
        
    def sum_of_right_leaf_nodes_iter(self,root):
        #stack
        s = []
        s.append(root)
        total = 0
        
        while len(s) > 0:
            
            temp = s.pop(0)
            
            if temp.LeftChild:
                s.append(temp.LeftChild)
            
            if temp.RightChild:
                s.append(temp.RightChild)
                
                if temp.RightChild.LeftChild == None and temp.RightChild.RightChild == None:
                    total = total + temp.RightChild.data
                    

                
        return total
 
                
                
            
                
        
            
bt = Binary_Tree(6)
bt.insert_node_in_Level(bt.root,4)
bt.insert_node_in_Level(bt.root,9)
bt.insert_node_in_Level(bt.root.LeftChild,4)
bt.insert_node_in_Level(bt.root.LeftChild,102)
#bt.insert_node_in_Level(bt.root.LeftChild,102)
bt.insert_node_in_Level(bt.root.RightChild,-1)
bt.insert_node_in_Level(bt.root.RightChild,100)
bt.insert_node_in_Level(bt.root.LeftChild.LeftChild,10)
#bt.insert_node_in_Level(bt.root.LeftChild.RightChild,5)
bt.insert_node_in_Level(bt.root.RightChild.RightChild,4)
bt.insert_node_in_Level(bt.root.RightChild.RightChild,88)
bt.level_order_traversal(bt.root)
print("\n") 

#bt.sum_of_left_leaf_nodes_recur(bt.root)
#bt.sum_of_left_leaf_nodes_iter(bt.root)
#bt.sum_of_right_leaf_nodes_recur(bt.root)
bt.sum_of_right_leaf_nodes_iter(bt.root)
# Out:
# 6
# 4 9
# 4 102 -1 100
# 10 4 88
# 190

# %%
## Find-sum-nodes-given-perfect-binary-tree

# %%
##Diagonal Sum of a Binary Tree (Start date-End date: 27th Jan,2021)
## Sum of all leaf nodes of binary tree(Start date-End date: 27th Jan,2021)
## Sum of heights of all individual nodes in a binary tree(Start date-End date: 28th Jan,2021)
## Count subtrees that sum up to a given value x.(Start date-End date: 27th Jan,2021)
## Subtree with given sum in a Binary Tree.(Start date-End date: 27th Jan,2021)
import queue
class Node():
    
    def __init__(self,data):
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
class Binary_Tree():
    
    def __init__(self,root):
        self.root = Node(root)
        
    def insert_node_in_Level(self,root,data):
        
        q = queue.Queue()
        q.put(root)
        
        newnode = Node(data)
        while not q.empty():
           
            temp = q.get()
            if temp.LeftChild == None:
                temp.LeftChild = newnode
                return
            else:
                q.put(temp)
                
            if temp.RightChild == None:
                temp.RightChild = newnode
                return
            else:
                q.put(temp)
                
    def level_order_traversal(self,root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
    def sum_of_diagonal_nodes(self,root):
        
        d = {}
        level = 0
        total = 0
        self.sum_of_diagonal_nodes_util(root,level,d)
        for k in d:
            print(d[k],end=" ")
        
        
    def sum_of_diagonal_nodes_util(self,root,level,d):
        
        if root == None:
            return
        
        if level in d:
            #d[level].append(root.data)
            d[level] += root.data
        else:
            d[level]=root.data
            
        self.sum_of_diagonal_nodes_util(root.LeftChild,level+1,d)
        self.sum_of_diagonal_nodes_util(root.RightChild,level,d)
        
    def sum_of_all_leaf_nodes(self,root):
        
        total = [0]
        self.sum_of_all_leaf_nodes_util(root,total)
        return total
        
    def sum_of_all_leaf_nodes_util(self,root,total):
        
        if root == None:
            return
        
        if root.LeftChild == None and root.RightChild == None:
            total[0]+= root.data
            print("root:",root.data,"total:",total)
            
        self.sum_of_all_leaf_nodes_util(root.LeftChild,total)
        self.sum_of_all_leaf_nodes_util(root.RightChild,total)
        
    def sum_of_height_of_individual_nodes(self,root):
        
        total=[0]
        self.sum_of_height_of_individual_nodes_util(root,total)
        return total
        
    def sum_of_height_of_individual_nodes_util(self,root,total):
        
        if root == None:
            return 0
        
        lheight = self.sum_of_height_of_individual_nodes_util(root.LeftChild,total)
        rheight = self.sum_of_height_of_individual_nodes_util(root.RightChild,total)
        
         
        total[0] += max(lheight,rheight) + 1
        return max(lheight,rheight)+1
        
    def count_subtrees(self,root,x):
        
        count = [0]
        self.count_subtrees_util(root,x,count)
        return count
        
        
    def count_subtrees_util(self,root,x,count):

        
        if root == None:
            return
        
        if root.data == x:
            count[0] += 1
            
        if root.LeftChild:
            if root.data + root.LeftChild.data == x:
                count[0] += 1
                
        if root.RightChild:
            if root.data + root.RightChild.data == x:
                count[0] += 1
                
        if root.LeftChild and root.RightChild:
            if root.data + root.LeftChild.data + root.RightChild.data == x:
                count[0] += 1
            
        self.count_subtrees_util(root.LeftChild,x,count)
        self.count_subtrees_util(root.RightChild,x,count)

    def subtree_with_given_sum(self,root,total):
        curr_sum = [0]
        return self.subtree_with_given_sum_util(root,total,curr_sum)
        
    def subtree_with_given_sum_util(self,root,total,curr_sum):
    
        if root == None:
            curr_sum[0] = 0
            return False

        
        right_sum = [0]
        left_sum = [0]
          
        ls = self.subtree_with_given_sum_util(root.LeftChild,total,left_sum)
        rs = self.subtree_with_given_sum_util(root.RightChild,total,right_sum)
        
        curr_sum[0] = left_sum[0] + right_sum[0] + root.data
        return ((ls or rs) or (curr_sum[0]==total))
  
    

        
bt = Binary_Tree(6)
bt.insert_node_in_Level(bt.root,4)
bt.insert_node_in_Level(bt.root,-6)
bt.insert_node_in_Level(bt.root.LeftChild,4)
bt.insert_node_in_Level(bt.root.LeftChild,-4)
#bt.insert_node_in_Level(bt.root.LeftChild,102)
bt.insert_node_in_Level(bt.root.RightChild,-1)
bt.insert_node_in_Level(bt.root.RightChild,100)
bt.insert_node_in_Level(bt.root.LeftChild.LeftChild,10)
#bt.insert_node_in_Level(bt.root.LeftChild.RightChild,5)
bt.insert_node_in_Level(bt.root.RightChild.RightChild,4)
bt.insert_node_in_Level(bt.root.RightChild.RightChild,88)

bt.level_order_traversal(bt.root)
print("\n")
#bt.sum_of_diagonal_nodes(bt.root)
#bt.sum_of_all_leaf_nodes(bt.root)
#bt.sum_of_height_of_individual_nodes(bt.root)
#bt.count_subtrees(bt.root,7)
bt.subtree_with_given_sum(bt.root,4)
# Out:
# 6
# 4 -6
# 4 -4 -1 100
# 10 4 88
#
# i am here
# i am here
# i am here
# i am here
# i am here
# i am here
# i am here
# i am here
# i am here
# i am here
# i am here
# True

# %%
## Difference between sums of odd level and even level nodes of a Binary Tree.

# %%
## Maximum spiral sum in Binary Tree.

# %%
##Find if there is a pair in root to a leaf path with sum equals to root’s data.[start-end: 20th Feb]
## Given a binary tree, find a pair of node in every path from root to leaf node where the sum of nodes equal root
## node's data. Return True or False.

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def FindNodeInPathFromRootToLeafNode(root):
    
    if root == None:
        return False
    
    res = []
    Rdata = root.data
    return (find_the_pair_of_nodes(root.LeftChild,Rdata,res) and
            find_the_pair_of_nodes(root.RightChild,Rdata,res))
    
def find_the_pair_of_nodes(root,Rdata,res):
    
    if root == None:
        return False
    
    diff = Rdata - root.data
   
    if diff in res:
        return True
   
    res.append(root.data)
    resL = find_the_pair_of_nodes(root.LeftChild,Rdata,res)
    resR = find_the_pair_of_nodes(root.RightChild,Rdata,res)
    res.pop(-1)
    return resL or resR


    
        
        
    
    
        
root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(10) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.LeftChild.LeftChild = Node(11)
root.LeftChild.LeftChild.RightChild = Node(8)
root.RightChild.LeftChild = Node(4)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(4)
#root.RightChild.RightChild.RightChild.RightChild = Node(66)
level_order_traversal(root)
print("\n")    
FindNodeInPathFromRootToLeafNode(root)
# Out:
# 14
# 2 10
# 3 18 4 -1
# 11 8 6 4
# True

# %%
##Find the maximum path sum between two leaves of a binary tree. - -[Start-23rd Feb/End:24th Feb]
## Find the sum and the path between two leaves of a binary tree.

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                

def max_leaf_to_leaf_sum(root):
    
    if root == None:
        return None
    global max_sum,max_path
    max_sum = -111111
    max_path,path = [],[]
    total = [0]
    find_max_leaf_to_leaf_sum(root,total,path)
    print("The maximum leaf to leaf sum:",max_sum)
    print("The maximum leaf to leaf sum path:",*max_path)
    
def find_max_leaf_to_leaf_sum(root,total,path):
    
    global max_sum,max_path
    
    if root == None:
        return None,[]
    
    path = []
    if root.LeftChild == None and root.RightChild == None:
        path.append(root.data)
        return root.data,path
    
    Lsum, Lpath = find_max_leaf_to_leaf_sum(root.LeftChild,total,path)
    Rsum, Rpath = find_max_leaf_to_leaf_sum(root.RightChild,total,path)
    
    if Lsum and Rsum:
        
        total[0] = Lsum + root.data + Rsum
        
        if total[0] > max_sum:
            max_sum = total[0]
            max_path = Lpath + [root.data] + Rpath[::-1]
           
        if Lsum > Rsum:

            Lpath.append(root.data)
            return max(Lsum,Rsum)+root.data,Lpath
        else:
            Rpath.append(root.data)
            return max(Lsum,Rsum)+root.data,Rpath
        
    if Rsum != None:

        Rpath.append(root.data)
        return root.data + Rsum,Rpath
    
    if Lsum != None:

        Lpath.append(root.data)
        return root.data + Lsum,Lpath
    
  
        

root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(10) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.RightChild.RightChild = Node(100)
root.LeftChild.LeftChild.LeftChild = Node(110)
root.LeftChild.LeftChild.RightChild = Node(8)
root.RightChild.LeftChild = Node(4)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(4)
#root.RightChild.RightChild.RightChild.RightChild = Node(66)
level_order_traversal(root)
print("\n") 
max_leaf_to_leaf_sum(root)
# Out:
# 14
# 2 10
# 3 18 4 -1
# 110 8 100 6 4
#
# The maximum leaf to leaf sum: 233
# The maximum leaf to leaf sum path: 110 3 2 18 100

# %%
##Maximum sum from a tree with adjacent levels not allowed 
## Try tomorrow...

# %%
##Find the maximum sum root to leaf path in a Binary Tree.[start:24 Feb end:24 Feb]
## Different way than mentioned in tutorialspoint.dev. The solution has 2 sub functions to first find the max node
## and print the sum. I did all the work in the same function.

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                

def max_root_to_leaf_sum(root):
    
    if root == None:
        return None
    
    global max_sum,max_path
    max_sum = -111111
    max_path,path = [],[]
    find_max_root_to_leaf_sum(root,path)
    print("The maximum root to leaf sum:",max_sum)
    print("The maximum root to leaf sum path:",*max_path[::-1])
    
    
def find_max_root_to_leaf_sum(root,path):
    
    global max_sum,max_path
    
    if root == None:
        return 0,[]
    path = []
    if root.LeftChild == None and root.RightChild == None:
        path.append(root.data)
        return root.data,path
    
    Lsum,Lpath = find_max_root_to_leaf_sum(root.LeftChild,path)
    Rsum,Rpath = find_max_root_to_leaf_sum(root.RightChild,path)
    #print("root:",root.data,"lsum:",Lsum,"lpath:",Lpath,"rsum:",Rsum,"Rpath:",Rpath)
  
    if Lsum > Rsum:

        max_sum = Lsum + root.data
        max_path = Lpath
        max_path.append(root.data)

    else:
        max_sum = Rsum + root.data
        max_path = Rpath
        max_path.append(root.data)
               
    return max_sum,max_path
               
    

    
    
        
root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(10) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.RightChild.RightChild = Node(10)
root.LeftChild.LeftChild.LeftChild = Node(11)
root.LeftChild.LeftChild.RightChild = Node(8)
root.RightChild.LeftChild = Node(4)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(49)
#root.RightChild.RightChild.RightChild.RightChild = Node(66)
level_order_traversal(root)
print("\n") 
max_root_to_leaf_sum(root)
# Out:
# 14
# 2 10
# 3 18 4 -1
# 11 8 10 6 49
#
# root: 3 lsum: 11 lpath: [11] rsum: 8 Rpath: [8]
# root: 18 lsum: 0 lpath: [] rsum: 10 Rpath: [10]
# root: 2 lsum: 14 lpath: [11, 3] rsum: 28 Rpath: [10, 18]
# root: -1 lsum: 6 lpath: [6] rsum: 49 Rpath: [49]
# root: 10 lsum: 4 lpath: [4] rsum: 48 Rpath: [49, -1]
# root: 14 lsum: 30 lpath: [10, 18, 2] rsum: 58 Rpath: [49, -1, 10]
# The maximum root to leaf sum: 72
# The maximum root to leaf sum path: 14 10 -1 49

# %%
##Sum of nodes on the longest path from root to leaf node.- -[start-end: 25th Feb]

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                

def sum_of_nodes_on_longest_path_from_root_to_leaf(root):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    global depth
    level = 0
    total = [0]
    find_longest_path(root,total,level)
    return total[0],depth
    
    
def find_longest_path(root,total,level):
    
    global depth
    
    if root == None:
        return 0,level

    
    l,Llevel = find_longest_path(root.LeftChild,total,level+1)
    r,Rlevel = find_longest_path(root.RightChild,total,level+1)
    
    if Llevel == Rlevel:
        total[0] = max(l,r) + root.data
        depth = Llevel
        
    elif Llevel > Rlevel:
        total[0] = l + root.data
        depth = Llevel
        
    elif Rlevel > Llevel:
        total[0] = r + root.data
        depth = Rlevel
    return total[0],depth
        
        
root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(10) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.RightChild.RightChild = Node(10)
root.LeftChild.LeftChild.LeftChild = Node(11)
root.LeftChild.LeftChild.RightChild = Node(8)
root.RightChild.LeftChild = Node(4)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(49)
#root.RightChild.RightChild.RightChild.RightChild = Node(66)
level_order_traversal(root)
print("\n")
sum_of_nodes_on_longest_path_from_root_to_leaf(root)
# Out:
# 14
# 2 10
# 3 18 4 -1
# 11 8 10 6 49
#
# root: 11 l: 0 Llevel: 4 r: 0 Rlevel: 4
# total: [11] depth: 4
# root: 8 l: 0 Llevel: 4 r: 0 Rlevel: 4
# total: [8] depth: 4
# root: 3 l: 11 Llevel: 4 r: 8 Rlevel: 4
# total: [14] depth: 4
# root: 10 l: 0 Llevel: 4 r: 0 Rlevel: 4
# total: [10] depth: 4
# root: 18 l: 0 Llevel: 3 r: 10 Rlevel: 4
# root: 2 l: 14 Llevel: 4 r: 28 Rlevel: 4
# total: [30] depth: 4
# root: 4 l: 0 Llevel: 3 r: 0 Rlevel: 3
# total: [4] depth: 3
# root: 6 l: 0 Llevel: 4 r: 0 Rlevel: 4
# total: [6] depth: 4
# root: 49 l: 0 Llevel: 4 r: 0 Rlevel: 4
# total: [49] depth: 4
# root: -1 l: 6 Llevel: 4 r: 49 Rlevel: 4
# total: [48] depth: 4
# root: 10 l: 4 Llevel: 3 r: 48 Rlevel: 4
# root: 14 l: 30 Llevel: 4 r: 58 Rlevel: 4
# total: [72] depth: 4
# (72, 4)

# %%
##Find the maximum sum leaf to root path in a Binary Tree. - - [start-end: 20th Feb-22nd feb]
## Internet solution(max_sum_leaf_to_root_path_1)
##max_sum_leaf_to_root_path - My solution

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
                
def max_sum_leaf_to_root_path_1(root):
    
    if root == None:
        return None
    
    global total
    total = [0]
   
    node = None
    
    target_node = find_target_leaf_node(root,total,node)
    x = print_leaf_to_root_path(root,target_node,total)
    return total[0]
    
    
def find_target_leaf_node(root,total,node):

    
    if root == None:
        return False
    
    if root.LeftChild == None and root.RightChild== None:
        return root.data
    
    l = find_target_leaf_node(root.LeftChild,total,node)
    r = find_target_leaf_node(root.RightChild,total,node)
    print("root:",root.data,"l:",l,"r:",r)
    target_node = max(l,r)
    print("target_node:",target_node)
    return target_node


def print_leaf_to_root_path(root,target_node,total):
    
    if root == None:
        return
    
    if root.data == target_node:
        print(root.data,end=" ")
        total[0] += root.data
        return True
    
    l = print_leaf_to_root_path(root.LeftChild,target_node,total)
    if l== True:
        print(root.data,end=" ")
        total[0] += root.data
        return True
    
   
    r = print_leaf_to_root_path(root.RightChild,target_node,total)
    if r == True:
        print(root.data,end=" ")
        total[0] += root.data
        return True
    

def max_leaf_to_root(root):
    
    if root == None:
        return None
    
    global max_sum,max_path
    max_sum = -111111
    max_path,path = [],[]
    find_max_leaf_to_root_sum(root,path)
    print("The maximum root to leaf sum:",max_sum)
    print("The maximum root to leaf sum path:",*max_path)
    
     
def find_max_leaf_to_root_sum(root,path):
    
    global max_sum,max_path
    
    if root == None:
        return 0,[]
    path = []
    if root.LeftChild == None and root.RightChild == None:
        path.append(root.data)
        return root.data,path
    
    Lsum,Lpath = find_max_leaf_to_root_sum(root.LeftChild,path)
    Rsum,Rpath = find_max_leaf_to_root_sum(root.RightChild,path)
    #print("root:",root.data,"Lsum:",Lsum,"Lpath:",Lpath,"Rsum:",Rsum,"Rpath:",Rpath)
     
    if Lsum > Rsum:
        max_sum = Lsum + root.data
        max_path = Lpath
        max_path.append(root.data)
    else:
        max_sum = Rsum + root.data
        max_path = Rpath
        max_path.append(root.data)
        
    return max_sum,max_path
    
    


    
    
    
    
    
    
root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(10) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.LeftChild.LeftChild = Node(11)
root.LeftChild.LeftChild.RightChild = Node(8)
root.LeftChild.RightChild.RightChild = Node(10)
root.RightChild.LeftChild = Node(4)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(4)
#root.RightChild.RightChild.RightChild.RightChild = Node(66)
level_order_traversal(root)
print("\n")    
#max_sum_leaf_to_root_path(root)    
    
max_leaf_to_root(root)
# Out:
# 14
# 2 10
# 3 18 4 -1
# 11 8 10 6 4
#
# root: 3 Lsum: 11 Lpath: [11] Rsum: 8 Rpath: [8]
# root: 18 Lsum: 0 Lpath: [] Rsum: 10 Rpath: [10]
# root: 2 Lsum: 14 Lpath: [11, 3] Rsum: 28 Rpath: [10, 18]
# root: -1 Lsum: 6 Lpath: [6] Rsum: 4 Rpath: [4]
# root: 10 Lsum: 4 Lpath: [4] Rsum: 5 Rpath: [6, -1]
# root: 14 Lsum: 30 Lpath: [10, 18, 2] Rsum: 15 Rpath: [6, -1, 10]
# The maximum root to leaf sum: 44
# The maximum root to leaf sum path: 10 18 2 14

# %%
##Find root of the tree where children id sum for every node is given.

# %%
##Sum of leaf nodes at minimum level/depth.(Recur)[start:24th Feb End: 25th Feb]
## The minimum depth of a binary tree is the number of nodes from the root node to the nearest leaf node.
##Sum of leaf nodes at minimum level/depth.(Iter)[start:25th Feb End: 25th Feb]
import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
                
def sum_of_minimum_depth_leaf_nodes(root):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    
    total = [0]
    level = 1
    global min_level,result
    min_level = 1234689987655
    find_minimum_depth(root,total,level)
    print("Minimum depth of the tree:",min_level)
    print("The sum of minimum depth leaf nodes:",total[0])

def find_minimum_depth(root,total,level):
    
    global min_level
    
    if root == None:
        return None,1234689987655
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data,level
    
    l,Llevel = find_minimum_depth(root.LeftChild,total,level+1)
    r,Rlevel = find_minimum_depth(root.RightChild,total,level+1)
    
    if l != None and r != None:
        if Llevel == Rlevel:
        
            total[0] = l + r
            min_level = Llevel
            
        elif Llevel > Rlevel:
            total[0] = r
            min_level = Rlevel
            
        else:
            total[0] = l
            min_level = Llevel

    elif l != None:
        total[0] = l
        min_level = Llevel
            
    elif r != None:
        total[0] = r
        min_level = Rlevel

    return total[0],min_level
        
def sum_of_minimum_depth_leaf_nodes_iter(root):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    q = []
    q.append(root)
    q.append(None)
    total = [0]
    min_level = 99999999999
    level = 1
    
    while len(q) > 1:
        
        temp = q.pop(0)
        if temp != None:
            
            if temp.LeftChild == None and temp.RightChild == None:
              
                min_level = min(min_level,level)
                if level == min_level:
                    total[0] += temp.data
                   
            else:
                if temp.LeftChild:
                    q.append(temp.LeftChild)
                if temp.RightChild:
                    q.append(temp.RightChild)
                    
        else:
            q.append(None)
            level = level + 1
            if level > min_level:
                break
            
    return min_level,total[0]


def sum_of_maximum_depth_leaf_nodes(root):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    
    total = [0]
    level = 1
    global max_level,result
    max_level = -1234689987655
    find_maximum_depth(root,total,level)
    print("Maximum depth of the tree:",max_level)
    print("The sum of maximum depth leaf nodes:",total[0])

def find_maximum_depth(root,total,level):
    
    global max_level
    
    if root == None:
        return None,-1234689987655
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data,level
    
    l,Llevel = find_maximum_depth(root.LeftChild,total,level+1)
    r,Rlevel = find_maximum_depth(root.RightChild,total,level+1)
    #print("root:",root.data,"l:",l,"Llevel:",Llevel,"r:",r,"Rlevel:",Rlevel)
    if l != None and r != None:
        if Llevel == Rlevel:
        
            total[0] = l + r
            max_level = Llevel
            
        elif Llevel > Rlevel:
            total[0] = l
            max_level = Llevel
            
        else:
            total[0] = r
            max_level = Rlevel

    elif l != None:
        total[0] = l
        #print("Llevel:",Llevel,"max_level:",max_level)
        max_level = Llevel
            
    elif r != None:
        total[0] = r
        max_level = Rlevel
        #print("root:",root.data,"Rlevel:",Rlevel,"max_level:",max_level)

    return total[0],max_level
        
            

root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(10) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.LeftChild.LeftChild = Node(11)
root.LeftChild.LeftChild.RightChild = Node(8)
root.LeftChild.RightChild.RightChild = Node(10)
root.RightChild.LeftChild = Node(4)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(4)
root.RightChild.RightChild.RightChild.RightChild = Node(66)
level_order_traversal(root)
print("\n")
#sum_of_minimum_depth_leaf_nodes(root)
#x,y = sum_of_minimum_depth_leaf_nodes_iter(root)
#print("Minimum depth of the tree:",x)
#print("The sum of minimum depth leaf nodes:",y)
sum_of_maximum_depth_leaf_nodes(root)
# Out:
# 14
# 2 10
# 3 18 4 -1
# 11 8 10 6 4
# 66
#
# Maximum depth of the tree: 5
# The sum of maximum depth leaf nodes: 66

# %%
## Root to leaf path sum equal to a given number. - - [start:26th Feb/end:27th Feb]

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def root_to_leaf_path_sum_equal_to_number(root,num):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    total = [0]
    return root_to_leaf_path_sum(root,total,num)
    
    
    
def root_to_leaf_path_sum(root,total,num):
    
    
    if root == None:
        return False

    if root.LeftChild == None and root.RightChild == None:
        
        var = total[0] + root.data
        return var == num
    
    total[0] = total[0] + root.data

    LFlag = root_to_leaf_path_sum(root.LeftChild,total,num)
    RFlag = root_to_leaf_path_sum(root.RightChild,total,num)
  
    total[0] = total[0] - root.data
    return (LFlag or RFlag) 
   
        
    
    
root = Node(14) 
root.LeftChild = Node(2) 
root.RightChild = Node(10) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(18)
root.LeftChild.LeftChild.LeftChild = Node(11)
root.LeftChild.LeftChild.RightChild = Node(8)
root.LeftChild.RightChild.RightChild = Node(10)
root.RightChild.LeftChild = Node(4)
root.RightChild.RightChild = Node(-1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(4)
root.RightChild.RightChild.RightChild.RightChild = Node(66)
level_order_traversal(root)
print("\n")    
root_to_leaf_path_sum_equal_to_number(root,47)
# Out:
# 14
# 2 10
# 3 18 4 -1
# 11 8 10 6 4
# 66
#
# root: 14 total: 14
# root: 2 total: 16
# root: 3 total: 19
# root: 11 var: 30
# root: 8 var: 27
# root: 3 total: [19] LFlag: False RFlag: False
# **root***: 3 total: [16]
# root: 18 total: 34
# root: 10 var: 44
# root: 18 total: [34] LFlag: False RFlag: False
# **root***: 18 total: [16]
# root: 2 total: [16] LFlag: False RFlag: False
# **root***: 2 total: [14]
# root: 10 total: 24
# root: 4 var: 28
# root: -1 total: 23
# root: 6 var: 29
# root: 4 total: 27
# root: 66 var: 93
# root: 4 total: [27] LFlag: False RFlag: False
# **root***: 4 total: [23]
# root: -1 total: [23] LFlag: False RFlag: False
# **root***: -1 total: [24]
# root: 10 total: [24] LFlag: False RFlag: False
# **root***: 10 total: [14]
# root: 14 total: [14] LFlag: False RFlag: False
# **root***: 14 total: [0]
# False

# %%
##Sum of all the numbers that are formed from root to leaf paths.[start:26th Feb/end:27th Feb]
##Given a binary tree, where every node value is a Digit from 1-9. Find the sum of all the numbers which are
##formed from root to leaf paths.

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def root_to_leaf_path_sum_equal_to_number(root,num):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    total = [0]
    return root_to_leaf_path_sum(root,total,num)
    
    
def root_to_leaf_path_sum(root,total,num):
    
    
    if root == None:
        return False

    if root.LeftChild == None and root.RightChild == None:
        
        var = total[0] + root.data
        return var == num
    
    total[0] = total[0] + root.data

    LFlag = root_to_leaf_path_sum(root.LeftChild,total,num)
    RFlag = root_to_leaf_path_sum(root.RightChild,total,num)
  
    total[0] = total[0] - root.data
    return (LFlag or RFlag) 
   
        
    
    
root = Node(4) 
root.LeftChild = Node(2) 
root.RightChild = Node(9) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(8)
root.LeftChild.LeftChild.LeftChild = Node(6)
root.LeftChild.LeftChild.RightChild = Node(7)
root.LeftChild.RightChild.RightChild = Node(0)
root.RightChild.LeftChild = Node(5)
root.RightChild.RightChild = Node(1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(4)
root.RightChild.RightChild.RightChild.RightChild = Node(9)
level_order_traversal(root)
print("\n")    
root_to_leaf_path_sum_equal_to_number(root,47)
# Out:
# 4
# 2 9
# 3 8 5 1
# 6 7 0 6 4
# 9
# False

# %%
### Sum of all the numbers that are formed from root to leaf paths. - - [start:28th Feb/end:28th Feb]

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def sum_of_all_numbers_from_root_to_leaf_path(root):
    
    if root == None:
        return -1
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    total = [0]
    num = " "
    find_numbers_formed_from_root_to_leaf(root,num,total)
    return total[0]
    
    
def find_numbers_formed_from_root_to_leaf(root,num,total):
    
    
    if root == None:
        return 0
    
    if root.LeftChild == None and root.RightChild == None:
        var = int(num + str(root.data))
        return var
    num = num + str(root.data)
    
    Lvar = find_numbers_formed_from_root_to_leaf(root.LeftChild,num,total)
    Rvar = find_numbers_formed_from_root_to_leaf(root.RightChild,num,total)

    if Lvar:
        total[0] = total[0] + Lvar
       
    if Rvar:
        total[0] = total[0] + Rvar
        
    num = num[:-1]
    
root = Node(4) 
root.LeftChild = Node(2) 
root.RightChild = Node(1) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(8)
root.LeftChild.LeftChild.LeftChild = Node(6)
root.LeftChild.LeftChild.RightChild = Node(7)
root.LeftChild.RightChild.RightChild = Node(0)
root.RightChild.LeftChild = Node(5)
root.RightChild.RightChild = Node(1)
root.RightChild.RightChild.LeftChild = Node(6)
root.RightChild.RightChild.RightChild = Node(4)
root.RightChild.RightChild.RightChild.RightChild = Node(1)
level_order_traversal(root)
print("\n")    
sum_of_all_numbers_from_root_to_leaf_path(root)
# Out:
# 4
# 2 1
# 3 8 5 1
# 6 7 0 6 4
# 1
#
# root: 3 Lvar: 4236 Rvar: 4237
# total: [4236]
# total: [8473]
# root: 8 Lvar: 0 Rvar: 4280
# total: [12753]
# root: 2 Lvar: None Rvar: None
# root: 4 Lvar: 0 Rvar: 41141
# total: [53894]
# root: 1 Lvar: 4116 Rvar: None
# total: [58010]
# root: 1 Lvar: 415 Rvar: None
# total: [58425]
# root: 4 Lvar: None Rvar: None
# 58425

# %%
##Difference between sums of odd level and even level nodes of a Binary Tree.- - [start:28th Feb/end:28th Feb]

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def odd_even_level(root):
    
    
    if root == None:
        return -1
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    q = []
    q.append(root)
    q.append(None)
    OLevelSum,ELevelSum = 0,0
    level = 1
    while len(q) > 1:
        
        temp = q.pop(0)
       
        if temp != None:

            if level % 2 == 0:
                ELevelSum += temp.data
            elif level % 2 != 0:
                OLevelSum += temp.data

            if temp.LeftChild:
                q.append(temp.LeftChild)
                
            if temp.RightChild:
                q.append(temp.RightChild)
                
        else:
            q.append(None)
            level += 1
    return ELevelSum-OLevelSum


def odd_even_level_recur(root):
    
    
    if root == None:
        return -1
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    EvenTotal,OddTotal = [0],[0]
    level = 1
    find_odd_even_sum(root,EvenTotal,OddTotal,level)
    return EvenTotal[0] - OddTotal[0]


def find_odd_even_sum(root,EvenTotal,OddTotal,level):
    
    if root == None:
        return 0
    if level % 2 == 0:
        EvenTotal[0] += root.data
    elif level % 2 != 0:
        OddTotal[0] += root.data
        
    find_odd_even_sum(root.LeftChild,EvenTotal,OddTotal,level+1)  
    find_odd_even_sum(root.RightChild,EvenTotal,OddTotal,level+1)
    
    
    
    
    
    
    
    
    
    
    
    
root = Node(4) 
root.LeftChild = Node(2) 
root.RightChild = Node(1) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(8)
root.LeftChild.LeftChild.LeftChild = Node(6)
root.LeftChild.LeftChild.RightChild = Node(7)
root.LeftChild.RightChild.RightChild = Node(0)
root.RightChild.LeftChild = Node(5)
root.RightChild.RightChild = Node(1)
root.RightChild.RightChild.LeftChild = Node(6)
#root.RightChild.RightChild.RightChild = Node(4)
#root.RightChild.RightChild.RightChild.RightChild = Node(1)
level_order_traversal(root)
print("\n")
#odd_even_level(root)
odd_even_level_recur(root)
# Out:
# 4
# 2 1
# 3 8 5 1
# 6 7 0 6
# 1

# %%
## Maximum spiral sum in Binary Tree. - - [start-end:March 1st]
## MAximum vertical sum in Binary Tree.- - [start-end:March 1st]
import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
                
                
                
def max_spiral_sum(root):
    
    if root == None:
        return -1
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    arr = []
    get_spiral_traversal(root,arr)
    return calculate_max_spiral_sum(arr)
    
    
    
def get_spiral_traversal(root,arr):
    
    
    s1,s2 = [],[]
    s1.append(root)
    while len(s1) > 0 or len(s2) > 0:
        
        while len(s1) > 0:
            
            temp = s1.pop(-1)
            
            arr.append(temp.data)
            if temp.LeftChild:
                s2.append(temp.LeftChild)
                
            if temp.RightChild:
                s2.append(temp.RightChild)
                
        while len(s2) > 0:
            
            temp = s2.pop(-1)
            arr.append(temp.data)
            if temp.RightChild:
                s1.append(temp.RightChild)
                
            if temp.LeftChild:
                s1.append(temp.LeftChild)
    return arr
            

def calculate_max_spiral_sum(arr):
    
    
    max_ending_here = 0
    max_so_far = arr[0]
    for i in range(0,len(arr)):
        
        max_ending_here = max_ending_here + arr[i]
        #print("max_ending_here:",max_ending_here)
        
        if max_so_far < max_ending_here:
            max_so_far = max_ending_here
            
        if max_ending_here < -1:
            max_ending_here = 0
    return max_ending_here

            
def max_vertical_sum(root):
    
    
    if root == None:
        return -1
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    mydict = {}
    vert_dist = 0
    cal_vertical_dist(root,mydict,vert_dist)
    for d in mydict:
        print(sum(mydict[d]),end=" ")
    
    
def cal_vertical_dist(root,mydict,vert_dist):
    
    if root == None:
        return 
    if vert_dist in mydict:
        mydict[vert_dist].append(root.data)
    else:
        mydict[vert_dist]= [root.data]
       
        
    cal_vertical_dist(root.LeftChild,mydict,vert_dist-1)
    cal_vertical_dist(root.RightChild,mydict,vert_dist+1)
        
    
  
    
root = Node(4) 
root.LeftChild = Node(2) 
root.RightChild = Node(1) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(8)
root.LeftChild.LeftChild.LeftChild = Node(6)
root.LeftChild.LeftChild.RightChild = Node(-7)
root.LeftChild.RightChild.RightChild = Node(0)
root.RightChild.LeftChild = Node(5)
root.RightChild.RightChild = Node(1)
root.RightChild.RightChild.LeftChild = Node(9)
#root.RightChild.RightChild.RightChild = Node(4)
#root.RightChild.RightChild.RightChild.RightChild = Node(1)
level_order_traversal(root)
print("\n")
#max_spiral_sum(root)
max_vertical_sum(root)
# Out:
# 4
# 2 1
# 3 8 5 1
# 6 -7 0 9
#
# 17 -5 3 6 10 1

# %%
##Replace each node in binary tree with the sum of its inorder predecessor and successor.[start-end:March 1st]

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
                
                
def replace_nodes(root):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    arr = []
    arr.append(0)
    store_inorder_traversal(root,arr)
    arr.append(0)
    i = [1]
    replace_nodes_with_sum(root,arr,i)
    
    
def store_inorder_traversal(root,arr):
    
    if root == None:
        return
    
    store_inorder_traversal(root.LeftChild,arr)
    
    arr.append(root.data)
    store_inorder_traversal(root.RightChild,arr)
    
def replace_nodes_with_sum(root,arr,i):
    
    if root == None:
        return
    
    replace_nodes_with_sum(root.LeftChild,arr,i)
    root.data = arr[i[0] - 1] + arr[i[0] + 1]
    i[0] += 1
    replace_nodes_with_sum(root.RightChild,arr,i)
    
    
    
    
    
    
    
    
root = Node(4) 
root.LeftChild = Node(2) 
root.RightChild = Node(1) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(8)
#root.LeftChild.LeftChild.LeftChild = Node(6)
#root.LeftChild.LeftChild.RightChild = Node(-7)
#root.LeftChild.RightChild.RightChild = Node(0)
root.RightChild.LeftChild = Node(5)
root.RightChild.RightChild = Node(1)
#root.RightChild.RightChild.LeftChild = Node(9)
#root.RightChild.RightChild.RightChild = Node(4)
#root.RightChild.RightChild.RightChild.RightChild = Node(1)
level_order_traversal(root)
print("\n")
replace_nodes(root)
print("After replacing the binary tree nodes with the sum.....")
print("\n")
level_order_traversal(root)
# Out:
# 4
# 2 1
# 3 8 5 1
#
# After replacing the binary tree nodes with the sum.....
#
#
# 13
# 11 6
# 2 6 5 1

# %%
## Find largest subtree sum in a tree.[start-end:March 2nd]
## Given a binary tree, task is to find subtree with maximum sum in tree.

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def largest_subtree_sum(root):
    
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    global max_sum
    max_sum = -1234569999
    curr_sum = [0]
    find_largest_subtree_sum(root,curr_sum)
    return max_sum
    
def find_largest_subtree_sum(root,curr_sum):
    
    global max_sum
    if root == None:
        return 0
    
    lSum = find_largest_subtree_sum(root.LeftChild,curr_sum)
    rSum = find_largest_subtree_sum(root.RightChild,curr_sum)
    #print("root:",root.data,"lsum:",lSum,"rSum:",rSum,"max_sum:",max_sum)
    curr_sum[0] = lSum + rSum + root.data
    max_sum = max(max_sum,curr_sum[0])
    #print("curr_sum:",curr_sum,"max_sum:",max_sum)
    return curr_sum[0]




                
root = Node(-4) 
root.LeftChild = Node(2) 
root.RightChild = Node(1) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(8)
#root.LeftChild.LeftChild.LeftChild = Node(6)
#root.LeftChild.LeftChild.RightChild = Node(-7)
#root.LeftChild.RightChild.RightChild = Node(0)
root.RightChild.LeftChild = Node(-5)
root.RightChild.RightChild = Node(1)
#root.RightChild.RightChild.LeftChild = Node(9)
#root.RightChild.RightChild.RightChild = Node(4)
#root.RightChild.RightChild.RightChild.RightChild = Node(1)
level_order_traversal(root)
print("\n")
largest_subtree_sum(root)
# Out:
# -4
# 2 1
# 3 8 -5 1
#
# root: 3 lsum: 0 rSum: 0 max_sum: -1234569999
# curr_sum: [3] max_sum: 3
# root: 8 lsum: 0 rSum: 0 max_sum: 3
# curr_sum: [8] max_sum: 8
# root: 2 lsum: 3 rSum: 8 max_sum: 8
# curr_sum: [13] max_sum: 13
# root: -5 lsum: 0 rSum: 0 max_sum: 13
# curr_sum: [-5] max_sum: 13
# root: 1 lsum: 0 rSum: 0 max_sum: 13
# curr_sum: [1] max_sum: 13
# root: 1 lsum: -5 rSum: 1 max_sum: 13
# curr_sum: [-3] max_sum: 13
# root: -4 lsum: 13 rSum: -3 max_sum: 13
# curr_sum: [6] max_sum: 13
# 13

# %%
##Maximum sum from a tree with adjacent levels not allowed.[start-end:March 2nd]
##Given a binary tree with positive integer values. Find the maximum sum of nodes such that we cannot pick two
##levels for computing sum.

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def max_sum_alternate_level(root):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    global EvenSum,OddSum
    
    EvenSum = [0]
    OddSum = [0]
    level = 1
    find_alternate_level_sum(root,level)
    print("EvenSum:",EvenSum,"OddSum:",OddSum)
    return max(EvenSum,OddSum)
    
    
def find_alternate_level_sum(root,level):
    
    if root == None:
        return 0
    
    if level % 2 == 0:
        EvenSum[0] += root.data
        
    elif level % 2 != 0:
        OddSum[0] += root.data
        
    find_alternate_level_sum(root.LeftChild,level + 1)
    find_alternate_level_sum(root.RightChild,level + 1)
    
    
    
                
root = Node(1) 
root.LeftChild = Node(2) 
root.RightChild = Node(3) 
root.LeftChild.LeftChild = Node(4) 
#root.LeftChild.RightChild = Node(8)
root.LeftChild.LeftChild.LeftChild = Node(17)
root.LeftChild.LeftChild.RightChild = Node(18)
root.LeftChild.LeftChild.LeftChild.LeftChild = Node(11)
root.LeftChild.LeftChild.RightChild.LeftChild = Node(12)
root.LeftChild.LeftChild.RightChild.RightChild = Node(13)
#root.LeftChild.RightChild.RightChild = Node(0)
root.RightChild.LeftChild = Node(5)
root.RightChild.RightChild = Node(6)
root.RightChild.LeftChild.LeftChild = Node(19)
root.RightChild.RightChild.LeftChild = Node(30)
#root.RightChild.RightChild.RightChild.RightChild = Node(1)
level_order_traversal(root)
print("\n")
max_sum_alternate_level(root)
# Out:
# 1
# 2 3
# 4 5 6
# 17 18 19 30
# 11 12 13
#
# EvenSum: [89] OddSum: [52]
# [89]

# %%
###Print all k-sum paths in a binary tree. - - [start-end:March 2nd]

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def print_k_sum_paths(root,k):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        if root.data == k:
            return root.data
        else:
            return None
    path = [] 

    find_k_sum_paths(root,k,path)
    

def find_k_sum_paths(root,k,path):
    
    if root == None:
        return

    path.append(root.data)

    find_k_sum_paths(root.LeftChild,k,path)
    find_k_sum_paths(root.RightChild,k,path)
    
    for i in range(0,len(path)):
        if sum(path[i:])== k:
            print(*path[i:])   
    
    path.pop(-1)
   
    return path



root = Node(1) 
root.LeftChild = Node(3) 
root.RightChild = Node(-1) 
root.LeftChild.LeftChild = Node(2) 
root.LeftChild.RightChild = Node(1)
#root.LeftChild.LeftChild.LeftChild = Node(6)
#root.LeftChild.LeftChild.RightChild = Node(-7)
root.LeftChild.RightChild.LeftChild = Node(1)
root.RightChild.LeftChild = Node(4)
root.RightChild.RightChild = Node(5)
root.RightChild.LeftChild.LeftChild = Node(1)
root.RightChild.LeftChild.RightChild = Node(2)
root.RightChild.RightChild.RightChild = Node(6)
#root.RightChild.RightChild.RightChild.RightChild = Node(1)
level_order_traversal(root)
print("\n")
print_k_sum_paths(root,4)
# Out:
# 1
# 3 -1
# 2 1 4 5
# 1 1 2 6
#
# 3 1
# 1 3
# -1 4 1
# 1 -1 4
# 4
# -1 5

# %%
##Merge Two Binary Trees by doing Node Sum (Recursive and Iterative)[start-end:March 2nd]

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def merge_two_binary_tree(root1,root2):
    
    if root1 == None and root2 == None:
        return None
    if root1 == None and root2 != None:
        return root2
    elif root1 != None and root2 == None:
        return root1
    
    return merge_trees(root1,root2)
    
    
def merge_trees(root1,root2):
    
    if root1 == None and root2 == None:
        return
    
    if root1 != None and root2 == None:
       
        newnode = Node(root1.data)
        return newnode
     
    elif root1 == None and root2 != None:
        
        newnode = Node(root2.data)
        return newnode   
    else:
        newnode = Node(root1.data + root2.data)
        
    newnode.LeftChild = merge_trees(root1.LeftChild,root2.LeftChild)
    newnode.RightChild = merge_trees(root1.RightChild,root2.RightChild) 
    return newnode
                
root1 = Node(1) 
root1.LeftChild = Node(3) 
root1.RightChild = Node(-10) 
root1.LeftChild.LeftChild = Node(2) 
root1.LeftChild.RightChild = Node(1)
root1.LeftChild.LeftChild.LeftChild = Node(7)

root2 = Node(2) 
root2.LeftChild = Node(8) 
root2.RightChild = Node(2) 
root2.LeftChild.LeftChild = Node(6) 
root2.LeftChild.RightChild = Node(4)
level_order_traversal(root1)
print("\n")
level_order_traversal(root2)
print("\n")

root3 = merge_two_binary_tree(root1,root2)

level_order_traversal(root3)
# Out:
# 1
# 3 -10
# 2 1
# 7
#
# 2
# 8 2
# 6 4
#
# 3
# 11 -8
# 8 5
# 7

# %%
import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                

def sum_of_deepest_nodes(root):
    
    if root == None:
        return -1
    global max_level
    max_level = -9999
    level = 1
    total = [0]
    sum_of_deepest_nodes_utility(root,total,level)
    return total
    
def sum_of_deepest_nodes_utility(root,total,level):
    
    global max_level
    
    if root == None:
        return -1
    print("root:",root.data,"level:",level,"max-level:",max_level)

    
    sum_of_deepest_nodes_utility(root.LeftChild,total,level+1)
    sum_of_deepest_nodes_utility(root.RightChild,total,level+1)
    
    if root.LeftChild == None and root.RightChild == None:
        if level > max_level:
            total[0] = 0 + root.data
            max_level = level
            print("total:",total[0])

        elif level == max_level:
            total[0] = total[0] + root.data
    return 

  
 

root = Node(1) 
root.LeftChild = Node(3) 
root.RightChild = Node(-1) 
root.LeftChild.LeftChild = Node(2) 
root.LeftChild.RightChild = Node(19)
#root.LeftChild.LeftChild.LeftChild = Node(6)
#root.LeftChild.LeftChild.RightChild = Node(-7)
root.LeftChild.RightChild.LeftChild = Node(29)
root.RightChild.LeftChild = Node(4)
root.RightChild.RightChild = Node(5)
root.RightChild.LeftChild.LeftChild = Node(-6)
root.RightChild.LeftChild.RightChild = Node(2)
#root.RightChild.RightChild.RightChild = Node(6)
#root.RightChild.RightChild.RightChild.RightChild = Node(1)
level_order_traversal(root)
print("\n")
sum_of_deepest_nodes(root)
# Out:
# 1
# 3 -1
# 2 19 4 5
# 29 -6 2
#
# root: 1 level: 1 max-level: -9999
# root: 3 level: 2 max-level: -9999
# root: 2 level: 3 max-level: -9999
# total: 2
# root: 19 level: 3 max-level: 3
# root: 29 level: 4 max-level: 3
# total: 29
# root: -1 level: 2 max-level: 4
# root: 4 level: 3 max-level: 4
# root: -6 level: 4 max-level: 4
# root: 2 level: 4 max-level: 4
# root: 5 level: 3 max-level: 4
# [25]
