# %%
#Start date: March 3rd, 2021

# %%
##Construct Tree from given Inorder and Preorder traversals.[start-end:3rd March]

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
                
def Construct_from_Inorder_And_Preorder(InOrd,PreOrd):
    
    if len(InOrd) != len(PreOrd):
        return None
    root = None
    root = Construct_binary_tree(root,InOrd,PreOrd)
    level_order_traversal(root)
   
    
def Construct_binary_tree(root,InOrd,PreOrd):
    
    
    if len(InOrd) == 0 or len(PreOrd) == 0:
        return None
    
    if len(InOrd) == 1 and len(PreOrd) == 1:
        return Node(InOrd[0])
    
    
    root = Node(PreOrd[0])
    ind = InOrd.index(root.data)
    
    if ind == 0:
        
        root.RightChild = Construct_binary_tree(root,InOrd[ind+1:],PreOrd[ind+1:])
    else:
    
        root.LeftChild = Construct_binary_tree(root,InOrd[0:ind],PreOrd[1:ind+1])
        root.RightChild = Construct_binary_tree(root,InOrd[ind+1:],PreOrd[ind+1:])

    if root.LeftChild != None or root.RightChild != None:
        return root

    else:
        return None

#Construct_from_Inorder_And_Preorder([4,2,8,1,6,3,9],[1,2,4,8,3,6,9])
#Construct_from_Inorder_And_Preorder([2,1,3,8,4],[1,2,8,3,4])
Construct_from_Inorder_And_Preorder([1,3,8,6,4,7,9],[1,8,3,4,6,7,9])
#Construct_from_Inorder_And_Preorder([1,8,3],[1,8,3])
#level_order_traversal(root)
# Out:
# 1
# 8
# 3 4
# 6 7
# 9

# %%
##Construct a tree from Inorder and Level order traversals(Optimized)[start-end:March 3rd]

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
                
def Construct_from_Inorder_And_LevelOrder(InOrd,LevelOrd):
    
    if len(InOrd) != len(LevelOrd):
        return None
    root = None
    Ldict={}
    for i in range(0,len(LevelOrd)):
        Ldict[LevelOrd[i]] = i
        
    root = Build_binary_tree(InOrd,Ldict)
    level_order_traversal(root)
   
    
def Build_binary_tree(InOrd,Ldict):
    
    
    if len(InOrd) == 0:
        return None
    
    if len(InOrd) == 1:
        return Node(InOrd[0])
    
    root_ind = 0
    for j in range(0,len(InOrd)):
        
        if Ldict[InOrd[j]] < Ldict[InOrd[root_ind]]:
            root_ind = j
 
    
    root = Node(InOrd[root_ind])
    ind = InOrd.index(root.data)

    root.LeftChild = Build_binary_tree(InOrd[0:ind],Ldict)
    root.RightChild = Build_binary_tree(InOrd[ind+1:],Ldict)

    if root.LeftChild != None or root.RightChild != None:
        return root

    else:
        return None
    
    
#Construct_from_Inorder_And_LevelOrder([4,8,6,1,7,3,9],[1,8,3,4,6,7,9])
#Construct_from_Inorder_And_LevelOrder([4,2,8,1,6,3,9],[1,2,3,4,8,6,9])
#Construct_from_Inorder_And_LevelOrder([3,1,-7,8,6,4],[1,3,8,-7,6,4])
Construct_from_Inorder_And_LevelOrder([3,8,1],[1,8,3])
# Out:
# 1
# 8
# 3

# %%
Construct Binary Tree from given Parent Array representation.

# %%
## Construct a Binary Tree from Postorder and Inorder.[start-end:March 3rd]

import queue
from collections import deque
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
                
def Construct_from_Inorder_And_PostOrder(InOrd,PostOrd):
    
    if len(InOrd) != len(PostOrd):
        return None
    #root = None
    root = Build_New_binary_tree(InOrd,PostOrd)
    level_order_traversal(root)
    
def Build_New_binary_tree(InOrd,PostOrd):
    
    if len(InOrd) == 0:
        return
    
    if len(InOrd) == 1:
        return Node(InOrd[0])
    
    root = Node(PostOrd[-1])
    ind = InOrd.index(root.data)
    
    if ind == 0:
        root.RightChild = Build_New_binary_tree(InOrd[ind+1:],PostOrd[ind:-1])
        
    elif ind == len(InOrd)-1:
        root.LeftChild = Build_New_binary_tree(InOrd[0:ind],PostOrd[0:ind])
        
    else:
        root.LeftChild = Build_New_binary_tree(InOrd[0:ind],PostOrd[0:ind])
        root.RightChild = Build_New_binary_tree(InOrd[ind+1:],PostOrd[ind:-1])
        
    if root.LeftChild != None or root.RightChild != None:
        return root

    else:
        return None
        
        
        
#Construct_from_Inorder_And_PostOrder([7,-1,14,4,3,6],[7,-1,4,6,3,14])
#Construct_from_Inorder_And_PostOrder([3,6,2],[6,3,2])
Construct_from_Inorder_And_PostOrder([1,3,9,4],[3,4,9,1])
# Out:
# 1
# 9
# 3 4

# %%
Construct a full binary tree from a preorder and postorder sequence.

# %%
Construct a full binary tree from preorder sequence with leaf node information.

# %%
If you are given two traversal sequences, can you construct the binary tree?

# %%
Construct Binary Tree from String with bracket representation

# %%
##Convert a given Binary Tree to Doubly Linked List | Set 3(Inorder Traversal)[start-end:March 3rd]
import queue
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')

def Convert_BT_To_DLL(root):
    
    global head,prev
    head,prev = None,None

    Convert(root)
    printDLL(head)


def Convert(root):
    
    global head,prev

    if root == None:
        return

    Convert(root.LeftChild)
    
    if prev == None:
        head = root          
    else:
        prev.RightChild = root
        root.LeftChild = prev
    prev = root
    
    Convert(root.RightChild)
    
    return head
        
def printDLL(curr):
    
    while curr:
        print(curr.data,end="-->")
        curr = curr.RightChild
    print(None)
    
    
    
    


            
root = Node(2) 
root.LeftChild = Node(4) 
root.RightChild = Node(7) 
#root.LeftChild.LeftChild = Node(3) 
#root.LeftChild.RightChild = Node(9)
#root.LeftChild.RightChild.RightChild = Node(100)
#root.LeftChild.LeftChild.LeftChild = Node(110)
#root.LeftChild.LeftChild.RightChild = Node(8)
root.RightChild.LeftChild = Node(18)
root.RightChild.RightChild = Node(5)
#root.RightChild.RightChild.LeftChild = Node(6)
#root.RightChild.RightChild.RightChild = Node(4)            
Convert_BT_To_DLL(root)         
            
#level_order_traversal(root)
# Out:
# 4-->2-->18-->7-->5-->None

# %%
##Convert a given Binary Tree to Doubly Linked List | Set 2 (Later)
## Convert a given Binary Tree to Doubly Linked List | Set 1(Later)

# %%
## Convert a given Binary Tree to Doubly Linked List(Level Order Traversal)[Start-End:4th March,2021]
## prev node == Leftchild, next node == RightChild

import queue
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
        
def Convert_BT_To_DLL_BFS(root):
    
    if root == None:
        return 
    
    q = []
    q.append(root)
    head,prev = None,None
    while len(q) > 0:
        
        curr = q.pop(0)
        
        if curr.LeftChild:
            q.append(curr.LeftChild)
        if curr.RightChild:
            q.append(curr.RightChild)
            
        if prev == None:
            head = curr
        else:
            curr.LeftChild = prev
            prev.RightChild = curr
            
        prev = curr
 
    print_DLL(head)

    
def print_DLL(curr):
    
    while curr:
        print(curr.data,end = "-->")
        curr = curr.RightChild
    print(None)
    

        

    
root = Node(2) 
root.LeftChild = Node(4) 
root.RightChild = Node(7) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(9)
#root.LeftChild.RightChild.RightChild = Node(100)
#root.LeftChild.LeftChild.LeftChild = Node(110)
#root.LeftChild.LeftChild.RightChild = Node(8)
root.RightChild.LeftChild = Node(18)
root.RightChild.RightChild = Node(5)
#root.RightChild.RightChild.LeftChild = Node(6)
#root.RightChild.RightChild.RightChild = Node(4)

Convert_BT_To_DLL_BFS(root)
# Out:
# 2-->4-->7-->3-->9-->18-->5-->None

# %%
##Convert a Binary Tree into Doubly Linked List in spiral fashion.[Start-End:4th March,2021]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
        
def Convert_BT_To_DLL_Spiral(root):
    
    if root == None:
        return 
    #deque
    dq = deque()
    dq.append(root)
    dq.append(None)
    head,prev = None,None
    
    while len(dq) > 1:
        
        curr = dq[0]
        if curr != None:
            
            if curr.LeftChild:
                dq.append(curr.LeftChild)
            if curr.RightChild:
                dq.append(curr.RightChild)
                
            if prev == None:
                head = curr
                
            else:
                curr.LeftChild = prev
                prev.RightChild = curr
            prev = curr 
            dq.popleft()
                
        elif curr == None:
            
            while dq[-1] != None:
                
                curr = dq[-1]
                if curr.RightChild:
                    dq.appendleft(curr.RightChild)
                if curr.LeftChild:
                    dq.appendleft(curr.LeftChild)
             
                curr.LeftChild = prev
                prev.RightChild = curr
                
                prev = curr 
                dq.pop()           
    print_DLL_Spiral(head)
    

def print_DLL_Spiral(curr):
    
    while curr:
        print(curr.data,end="-->")
        curr = curr.RightChild
    print(None)
                
root = Node(2) 
root.LeftChild = Node(4) 
root.RightChild = Node(7) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(9)
root.LeftChild.RightChild.RightChild = Node(100)
root.LeftChild.LeftChild.LeftChild = Node(110)
root.LeftChild.LeftChild.RightChild = Node(8)
root.RightChild.LeftChild = Node(18)
root.RightChild.RightChild = Node(5)
#root.RightChild.RightChild.LeftChild = Node(6)
#root.RightChild.RightChild.RightChild = Node(4)
level_order_traversal(root)
print("\n")
Convert_BT_To_DLL_Spiral(root)
# Out:
# 2
# 4 7
# 3 9 18 5
# 110 8 100
#
# 2-->7-->4-->3-->9-->18-->5-->100-->8-->110-->None

# %%
##Change a Binary Tree so that every node stores sum of all nodes in left subtree.[start-end:March 6th]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
        
def Convert_Binary_Tree_To_Left_Subtree_Sum(root):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return 0
    val = 0
    x = Construct_Left_Subtree_Sum(root.LeftChild,val)
    root.data = x
    
def Construct_Left_Subtree_Sum(root,val):
    
    if root == None:
        return 0
    
    Lsum = Construct_Left_Subtree_Sum(root.LeftChild,val)
    Rsum = Construct_Left_Subtree_Sum(root.RightChild,val)

    root.data = Lsum + root.data
    return root.data + Rsum


root = Node(2) 
root.LeftChild = Node(4) 
root.RightChild = Node(7) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(9)
#root.LeftChild.RightChild.RightChild = Node(100)
#root.LeftChild.LeftChild.LeftChild = Node(110)
#root.LeftChild.LeftChild.RightChild = Node(8)
root.RightChild.LeftChild = Node(18)
root.RightChild.RightChild = Node(5)
#root.RightChild.RightChild.LeftChild = Node(6)
#root.RightChild.RightChild.RightChild = Node(4)
level_order_traversal(root)
print("\n")

Convert_Binary_Tree_To_Left_Subtree_Sum(root)
level_order_traversal(root)
# Out:
# 2
# 4 7
# 3 9 18 5
#
# 16
# 7 7
# 3 9 18 5

# %%
##Convert a given Binary tree to its Sum Tree.[start-end:March 5th]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
        
def Convert_Binary_Tree_Sum_Tree(root):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return 0
    val = 0
    Construct_Sum_Tree(root,val)
    
    
def Construct_Sum_Tree(root,val):
    
    if root == None:
        return 0
    
    Lsum = Construct_Sum_Tree(root.LeftChild,val)
    Rsum = Construct_Sum_Tree(root.RightChild,val)
    
    val = Lsum + Rsum + root.data
    root.data = Lsum + Rsum
    return val


root = Node(2) 
root.LeftChild = Node(4) 
root.RightChild = Node(7) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(9)
#root.LeftChild.RightChild.RightChild = Node(100)
#root.LeftChild.LeftChild.LeftChild = Node(110)
#root.LeftChild.LeftChild.RightChild = Node(8)
root.RightChild.LeftChild = Node(18)
root.RightChild.RightChild = Node(5)
#root.RightChild.RightChild.LeftChild = Node(6)
#root.RightChild.RightChild.RightChild = Node(4)
level_order_traversal(root)
print("\n")

Convert_Binary_Tree_Sum_Tree(root)
level_order_traversal(root)
# Out:
# 2
# 4 7
# 3 9 18 5
#
# root: 3 val: 3
# root.data.before: 3
# root.data.after: 0
# root: 9 val: 9
# root.data.before: 9
# root.data.after: 0
# root: 4 val: 16
# root.data.before: 4
# root.data.after: 12
# root: 18 val: 18
# root.data.before: 18
# root.data.after: 0
# root: 5 val: 5
# root.data.before: 5
# root.data.after: 0
# root: 7 val: 30
# root.data.before: 7
# root.data.after: 23
# root: 2 val: 48
# root.data.before: 2
# root.data.after: 46
# 46
# 12 23
# 0 0 0 0

# %%
##Convert a Binary Tree into its Mirror Tree.[start-end: March 6th]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
        
def Convert_Binary_Tree_Into_Mirror_Tree(root):
    
    if root == None:
        return None
    
    
    if root.LeftChild != None and root.RightChild != None:
        temp = root.LeftChild
        root.LeftChild = root.RightChild
        root.RightChild = temp
        
    
    Convert_Binary_Tree_Into_Mirror_Tree(root.LeftChild)
    Convert_Binary_Tree_Into_Mirror_Tree(root.RightChild)

    
root = Node(2) 
root.LeftChild = Node(4) 
root.RightChild = Node(7) 
root.LeftChild.LeftChild = Node(3) 
root.LeftChild.RightChild = Node(9)
root.RightChild.LeftChild = Node(18)
root.RightChild.RightChild = Node(5)
level_order_traversal(root)
print("\n")
Convert_Binary_Tree_Into_Mirror_Tree(root)
level_order_traversal(root)
print("\n")
# Out:
# 2
# 4 7
# 3 9 18 5
#
# 2
# 7 4
# 5 18 9 3

# %%
##Flip Binary Tree[Extremely Hard]

# %%
##Determine-if-binary-tree-can-converted-to-another-by-doing-any-number-swaps-of-left-right-child.

# %%
##Tree Isomorphism Problem..[start-end: March 6th]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                

def Isomorphic_Trees(root1,root2):
    
    if root1 == None or root2 == None:
        return False
    
    flag = True
        
    return Check_Isomorphism(root1,root2)
    
    
def Check_Isomorphism(root1,root2):
    
    
    if root1 == None and root2 == None:
        return True
    
    if root1 == None or root2 == None:
        return False
    
    if root1.data != root2.data:
        return False

        
    return ((Check_Isomorphism(root1.LeftChild,root2.LeftChild) and Check_Isomorphism(root1.RightChild,root2.RightChild))
             or (Check_Isomorphism(root1.LeftChild,root2.RightChild) and Check_Isomorphism(root1.RightChild,root2.LeftChild)))
    
        
        
        
        
        
        

root1 = Node(2) 
root1.LeftChild = Node(4) 
root1.RightChild = Node(7) 
root1.LeftChild.LeftChild = Node(3) 
root1.LeftChild.RightChild = Node(9)
root1.RightChild.LeftChild = Node(18)
root1.RightChild.RightChild = Node(5)
level_order_traversal(root1)
print("\n")
root2 = Node(2) 
root2.LeftChild = Node(4) 
root2.RightChild = Node(7) 
root2.LeftChild.LeftChild = Node(9) 
root2.LeftChild.RightChild = Node(3)
root2.RightChild.LeftChild = Node(5)
root2.RightChild.RightChild = Node(18)
level_order_traversal(root2)
print("\n")
Isomorphic_Trees(root1,root2)
# Out:
# 2
# 4 7
# 3 9 18 5
#
# 2
# 4 7
# 9 3 5 18
# True

# %%
###Construct Binary Tree from given Parent Array representation....[start-end: March 6th]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')

def Construct_Tree_From_Parent_Array(parent):
    
    pdict = {}
    for i in range(0,len(parent)):
        
        pdict[i] = Node(i)
    #print("dict:",pdict)
        
    root = None
    for i in range(0,len(parent)):
        #print("i:",i,"parent[i]:",parent[i])
        if parent[i] == -1:
            root = pdict[i]
            
        else:
            
            if pdict[parent[i]].LeftChild == None:
                pdict[parent[i]].LeftChild = pdict[i]
                
            elif pdict[parent[i]].RightChild == None:
                pdict[parent[i]].RightChild = pdict[i]
    return root
                
    
    
root = Construct_Tree_From_Parent_Array([1,5,5,2,2,-1,3])
level_order_traversal(root)
# Out:
# 5
# 1 2
# 0 3 4
# 6

# %%
###### Construct Binary Tree from String with bracket representation.[start-end:March 8th]
### Extremely difficult

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')

                
def Construct_Binary_Tree_From_String(str1):
    
    global sLen,neg,start        
    start = 0
    sLen = len(str1)
    root =  Construct_Binary_Tree_Helper(str1)
    level_order_traversal(root)
    
def Construct_Binary_Tree_Helper(str1):
    
    global sLen,neg,start
   
    if start > sLen:
        return None
    
    if str1[start] == "-":
        neg = True
        start += 1
        
    ## This section is to incorporate negative number
    if neg == True:
        
        num = "-" + str1[start]
        root = Node(num)
        neg = False
        start += 1
        
    else:
        root = Node(str1[start])
        start += 1
             
    if start > sLen:
        return root
    
    if start < sLen and str1[start] == "(":
        
        start = start + 1
        root.LeftChild = Construct_Binary_Tree_Helper(str1)
        
    if start < sLen and str1[start] == ")":
        
        start += 1
        return root
    #print("****before---going--to---right****")    
    #print("root:",root.data,"start:",start)
    if start < sLen and str1[start] == "(":
        
        start = start + 1
        root.RightChild = Construct_Binary_Tree_Helper(str1)
        
    if start < sLen and str1[start] == ")":
        start += 1
        return root
    return root
        


            
        
#x = Construct_Binary_Tree_From_String("-1(2)(3)")
Construct_Binary_Tree_From_String("-4(2(3)(1))(6(5))")
# Out:
# -4
# 2 6
# 3 1 5

# %%
###Construct String from Binary Tree with bracket representation.- - [start-end:March 8th]
## my own thougt..but learned optimized solution from internet
import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def Construct_String_From_Binary_Tree(root):
    
    result = ""
    if root == None:
        return result
    
    lFlag = True
    rFlag = True
    x = helper_function(root,result,lFlag,rFlag)
    
    print(x)

def helper_function(root,result,lFlag,rFlag):
    
    if root == None:
        result += "("
        return result
    
    if lFlag == True and rFlag == True:
        result = str(root.data)
        
    if lFlag == True and rFlag == False:
        result += "(" + str(root.data)
    
    if rFlag == True and lFlag == False:
        result += "(" + str(root.data)
        
    if root.LeftChild == None and root.RightChild == None:
        return result
    
   
    lResult = helper_function(root.LeftChild,result,True,False)
    if lResult:
        result = lResult + ")"
        
    rResult = helper_function(root.RightChild,result,False,True)
    if rResult:
        result = rResult + ")"
    return result

                
root1 = Node(1) 
root1.LeftChild = Node(2) 
root1.RightChild = Node(3) 
#root1.LeftChild.LeftChild = Node(4) 
root1.LeftChild.RightChild = Node(4)
#root1.RightChild.LeftChild = Node(18)
#root1.RightChild.RightChild = Node(5)
level_order_traversal(root1)
print("\n")
Construct_String_From_Binary_Tree(root1)
# Out:
# 1
# 2 3
# 4
#
# 1(2()(4))(3)

# %%
##Construct String from Binary Tree with bracket representation.- - [start-end:March 8th]
## Optimized Solution

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def Construct_String_From_Binary_Tree(root):
    
    result = ""
    
    if root == None:
        return result

    x = helper_function(root,result)
    print(x)
    
def helper_function(root,result):
    
    if root == None:
        return ""
    
    if root.LeftChild == None and root.RightChild == None:
        return str(root.data)
    
    result = str(root.data)
    if root.LeftChild:
        
        result = result + "(" + helper_function(root.LeftChild,result) + ")"
    else:
        result = result + "(" + ")"
        
    if root.RightChild:
        result = result + "(" + helper_function(root.RightChild,result) + ")"
        
    return result
        


  
        
                
root1 = Node(1) 
root1.LeftChild = Node(2) 
root1.RightChild = Node(3) 
#root1.LeftChild.LeftChild = Node(4) 
root1.LeftChild.RightChild = Node(4)
#root1.RightChild.LeftChild = Node(18)
#root1.RightChild.RightChild = Node(5)
level_order_traversal(root1)
print("\n")
Construct_String_From_Binary_Tree(root1)
# Out:
# 1
# 2 3
# 4
#
# root: 2 result: 2()(4)
# root: 1 result: 1(2()(4))(3)
# 1(2()(4))(3)

# %%
##Convert left-right representation of a binary tree to down-right. OR Convert normal binary tree to Left-Child
##Right-Sibling binary tree. [start-end: March 8th]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def Convert_LeftRight_to_DownRight(root):
    
    if root == None:
        return 
    
    Convert_LeftRight_to_DownRight(root.LeftChild)
    Convert_LeftRight_to_DownRight(root.RightChild)
    
    if root.LeftChild == None:
        root.LeftChild = root.RightChild
        root.RightChild = None
        
    else:
        root.LeftChild.RightChild = root.RightChild
        root.RightChild = None
    


root1 = Node(1) 
root1.LeftChild = Node(2) 
root1.RightChild = Node(3) 
#root1.LeftChild.LeftChild = Node(4) 
root1.LeftChild.RightChild = Node(4)
#root1.RightChild.LeftChild = Node(18)
#root1.RightChild.RightChild = Node(5)
level_order_traversal(root1)
print("\n")
Construct_LeftRight_to_DownRight(root1)
level_order_traversal(root1)
# Out:
# 1
# 2 3
# 4
#
# 1
# 2
# 4 3

# %%
##Convert given binary tree to full tree by removing half nodes.[Start-End: March 9th, 2021]
import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def check_leaf_node(root):
    
    return (root.LeftChild == None and root.RightChild == None)

def Convert_BTree_FTree_RemovingHalfNodes(root,prev = None):
    
    if root == None:
        return None

    root.LeftChild = Convert_BTree_FTree_RemovingHalfNodes(root.LeftChild,prev)
    root.RightChild = Convert_BTree_FTree_RemovingHalfNodes(root.RightChild,prev)
    

    if (root.LeftChild and root.RightChild) or check_leaf_node(root):
        return root
    if root.LeftChild:
        return root.LeftChild
    if root.RightChild:
        return root.RightChild

        
root1 = Node(0) 
root1.LeftChild = Node(1) 
root1.RightChild = Node(2) 
root1.LeftChild.LeftChild = Node(3) 
#root1.LeftChild.RightChild = Node(4)
root1.RightChild.LeftChild = Node(4)
root1.LeftChild.LeftChild.LeftChild = Node(5)
root1.RightChild.LeftChild.LeftChild = Node(6)
root1.RightChild.LeftChild.RightChild = Node(7)
level_order_traversal(root1)
print("\n")
Convert_BTree_FTree_RemovingHalfNodes(root1)
level_order_traversal(root1)
# Out:
# 0
# 1 2
# 3 4
# 5 6 7
#
# 0
# 5 4
# 6 7

# %%
##Convert a given Binary tree to a tree that holds Logical AND property.[Start-End: March 9th, 2021]
import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def Tree_With_AND_Property(root):
    
    if root == None:
        return None
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    lResult = Tree_With_AND_Property(root.LeftChild)
    rResult = Tree_With_AND_Property(root.RightChild)
    
    if lResult != None and rResult != None:
        root.data = lResult and rResult
        return root.data
    
    if lResult != None and rResult == None:
        root.data = lResult
        return root.data
    
    if rResult != None and lResult == None:
        root.data = rResult
        return root.data
        
    
    
root1 = Node(1) 
root1.LeftChild = Node(1) 
root1.RightChild = Node(0) 
root1.LeftChild.LeftChild = Node(0) 
root1.LeftChild.RightChild = Node(1)
root1.RightChild.LeftChild = Node(1)
root1.RightChild.RightChild = Node(1)
level_order_traversal(root1)
print("\n")    
Tree_With_AND_Property(root1)
level_order_traversal(root1)
# Out:
# 1
# 1 0
# 0 1 1 1
#
# 0
# 0 1
# 0 1 1 1

# %%
##Convert an arbitrary Binary Tree to a tree that holds Children Sum Property.[start-end: March 9th]
## My own solution..

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def Binary_Tree_With_Children_Sum_Property(root):
    
    if root == None:
        return None
    
    global diff
    diff = 0
    Construct_Tree_With_Children_Sum_Property(root)
    level_order_traversal(root)
    
def Construct_Tree_With_Children_Sum_Property(root):
    
    if root == None:
        return 0
    
    if root.LeftChild == None and root.RightChild == None:
        return root.data
    
    lSum = Construct_Tree_With_Children_Sum_Property(root.LeftChild)
    rSum = Construct_Tree_With_Children_Sum_Property(root.RightChild)
    diff = root.data - (lSum + rSum)

    
    if diff == 0:
        return root.data
    
    if diff < 0:
        root.data = root.data + abs(diff)
        return root.data
    
    if diff > 0:
        
        if root.LeftChild:
            
            root.LeftChild.data = root.LeftChild.data + abs(diff)
           
            Construct_Tree_With_Children_Sum_Property(root.LeftChild)
            Construct_Tree_With_Children_Sum_Property(root.RightChild)
            return root.data
        else: 
            
            root.RightChild.data = root.RightChild.data + abs(diff)
            Construct_Tree_With_Children_Sum_Property(root.RightChild)
            return root.data
        
   
            
    
    

root1 = Node(50) 
root1.LeftChild = Node(27)
root1.RightChild = Node(18) 
root1.LeftChild.LeftChild = Node(8)
root1.LeftChild.LeftChild.LeftChild = Node(6)
#root1.LeftChild.RightChild = Node(6)
#root1.LeftChild.RightChild.LeftChild = Node(7)
#root1.LeftChild.RightChild.RightChild = Node(4)
root1.RightChild.LeftChild = Node(3)
root1.RightChild.RightChild = Node(4)
level_order_traversal(root1)
print("\n")
Binary_Tree_With_Children_Sum_Property(root1)
# Out:
# 50
# 27 18
# 8 3 4
# 6
#
# 50
# 32 18
# 32 14 4
# 32

# %%
##Construct a Binary Tree from Ancestor Matrix.

# %%
##Convert Ternary Expression to a Binary Tree.[Start-End:March 9th]
## After converting ternary expression to a binary tree, i was unable to print level order traversal.
import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        var = []
        q.put(root)
        q.put(None)
      
        
        while q.qsize() > 1:
            
            temp = q.get()
            
            if temp != None:
                print(temp.data,end=" ")
                if temp.LeftChild:
                    
                    q.put(temp.LeftChild) 

                if temp.RightChild:
                   
                    q.put(temp.RightChild)

            else:
                q.put(None)
                print(end='\n')
                
def Convert_TExp_Binary_Tree(str1):
    
    if str1 == "" or len(str1)==0:
        return ""
    
    global start
    start = 0
    #root = None
    x = Convert_TExp_Binary_Tree_helper(str1)
    print_Tree(x)
    
def Convert_TExp_Binary_Tree_helper(str1):
    
    global start
    if start > len(str1):
        return 
    
    root = Node(str1[start])
    start += 1
    #print("root:",root.data,"start:",start)
    if start < len(str1) and str1[start] == "?":
        start = start + 1
        root.LeftChild = Convert_TExp_Binary_Tree_helper(str1)
          
    elif start < len(str1) and str1[start] == ":":
            start = start + 1
            root.RightChild = Convert_TExp_Binary_Tree_helper(str1)

  
    return root

def print_Tree(curr):
    
    if curr == None:
        return
    
    print(curr.data,end=" ")
    print_Tree(curr.LeftChild)
    print_Tree(curr.RightChild)

#Convert_TExp_Binary_Tree("a?b?c:d:e")
Convert_TExp_Binary_Tree("a?c?w:x:e?f:g")
# Out:
# a c w x e f g

# %%
#Flatten Binary Tree.(Recursion-Postorder)[start-end:March 10th][Space-Time Complexity:O(N)]
#Flatten Binary Tree.(Using Stack)[start-end:March 10th][Space-Time Complexity:O(N)]
#Flatten Binary Tree.(Using Morris_Traversal)[start-end:March 10th][Space-O(1)-Time Complexity:O(N)]

import queue
from collections import deque
class Node:
    
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def level_order_traversal(root):
        
        q = queue.Queue()
        var = []
        q.put(root)
        q.put(None)
      
        
        while q.qsize() > 1:
            
            temp = q.get()
            
            if temp != None:
                print(temp.data,end=" ")
                if temp.LeftChild:
                    
                    q.put(temp.LeftChild) 

                if temp.RightChild:
                   
                    q.put(temp.RightChild)

            else:
                q.put(None)
                print(end='\n')
                
def Flatten_Binary_Tree_PostOrder(root):
    
    if root == None:
        return None
    
    global prev
    ## I am trying to make an empty node, that's why first i created with data -1 and then make node == None.
    prev = Node(-1)
    prev == None
   
    Flatten_Binary_Tree_PostOrder_Helper(root)
    display_Flatten_Binary_Tree(prev)
  
    #return ret 
    
def Flatten_Binary_Tree_PostOrder_Helper(root):
    
    global prev
    
    if root == None:
        return None
   
    Flatten_Binary_Tree_PostOrder_Helper(root.RightChild)
    Flatten_Binary_Tree_PostOrder_Helper(root.LeftChild)
    
    root.RightChild = prev
    root.LeftChild = None
    prev = root
   
    
def display_Flatten_Binary_Tree(root):
    
    curr = root
    
    while curr != None:
        print(curr.data,end="-->")
        curr = curr.RightChild
    print(None)
    

def Flatten_Binary_Tree_Stack(root):
    
    if root == None:
        return None
    
    #stack
    s = []
    s.append(root)
    
    while len(s) > 0:
        
        curr = s.pop(-1)
        
        if curr.RightChild:
            s.append(curr.RightChild)
        if curr.LeftChild:
            s.append(curr.LeftChild)

        if len(s) > 0:
            curr.RightChild = s[-1]
        curr.LeftChild = None
        
    display_Flatten_Binary_Tree(root)
    

def Flatten_Binary_Tree_Morris(root):
    
    if root == None:
        return None
    
    curr = root
    
    while curr:
        
        if curr.LeftChild:
            prev = curr.LeftChild
            while prev.RightChild:
                prev = prev.RightChild
            prev.RightChild = curr.RightChild
            curr.RightChild = curr.LeftChild
            curr.LeftChild = None
        curr = curr.RightChild
            
    display_Flatten_Binary_Tree(root)
            
    

    
 
    

    
    
root1 = Node(50) 
root1.LeftChild = Node(27)
root1.RightChild = Node(18) 
root1.LeftChild.LeftChild = Node(8)
root1.LeftChild.LeftChild.LeftChild = Node(6)
#root1.LeftChild.RightChild = Node(6)
#root1.LeftChild.RightChild.LeftChild = Node(7)
#root1.LeftChild.RightChild.RightChild = Node(4)
root1.RightChild.LeftChild = Node(3)
root1.RightChild.RightChild = Node(4)
level_order_traversal(root1)
print("\n")
#Flatten_Binary_Tree_PostOrder(root1)
#Flatten_Binary_Tree_Stack(root1)
Flatten_Binary_Tree_Morris(root1)
# Out:
# 50
# 27 18
# 8 3 4
# 6
#
# 50-->27-->8-->6-->18-->3-->4-->None
