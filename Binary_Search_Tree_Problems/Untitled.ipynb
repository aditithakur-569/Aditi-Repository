# %%
##Merge two BSTs into a doubly-linked list in sorted order. - - [start-end: April 16th]

import queue
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
def insert_node_iter(root,data):
    
    if root == None:
        root = Node(data)
        return root
        
    curr = root
    parent = None
    while curr != None:
        
        parent = curr
        if data < curr.data:
            curr = curr.LeftChild
            
        elif data > curr.data:
            curr = curr.RightChild
            
    if data < parent.data:
        parent.LeftChild = Node(data)
    elif data > parent.data:
        parent.RightChild = Node(data)
        
    return root
        
        
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def Convert_BST_Into_DLL(root):
    
    if root == None:
        return None
    
    global head, prev
    head,prev = None, None
    return Convert_BST_Into_DLL_Utility(root)

    
def Convert_BST_Into_DLL_Utility(root):
    global head, prev
    
    if root == None:
        return
    
    Convert_BST_Into_DLL_Utility(root.LeftChild)
    if prev == None:
        head = root
        prev = root
    else:
        root.LeftChild = prev
        prev.RightChild = root
        prev = root
    Convert_BST_Into_DLL_Utility(root.RightChild)
    
    return head
    

def print_DLL(head):
    
    curr =head
    while curr:
        print(curr.data,end = "-->")
        curr = curr.RightChild
    print(None)
    
def Merge_Two_BSTs_In_DLL(root1, root2):
    
    if root1 == None or root2 == None:
        return None
    head1,head2 = None,None
    head1 = Convert_BST_Into_DLL(root1)
    head2 = Convert_BST_Into_DLL(root2)
    #print("head1:",head1.data,"head2:",head2.data)
    print_DLL(head1)
    print("\n")
    print_DLL(head2)
    x = merge_Two_DLLs(head1,head2)
    print_DLL(x)
    
def merge_Two_DLLs(head1,head2):
    
    head,prev = None,None
    
    if head1 is None:
        return head2
    
    if head2 is None:
        return head1
    print("\n")
    while head1 and head2:
        #print("head1:",head1.data,"head2:",head2.data)
        if head1.data < head2.data:

            if prev == None:
                head = head1
                prev = head

            else:
                prev.RightChild = head1
                head1.LeftChild = prev
                prev = head1

            head1 = head1.RightChild

        elif head1.data > head2.data:

            if prev == None:
                head = head2
                prev = head

            else:
                #print("prev:",prev.data)
                prev.RightChild = head2
                head2.LeftChild = prev
                prev = head2
                
            head2 = head2.RightChild
            #print("head:",head.data,"prev:",prev.data)
            
        
                
                
            
    if head2:
        prev.RightChild = head2
        head2.LeftChild = prev
        
    if head1:
        prev.RightChild = head1
        head1.LeftChild = prev
            
    return head
            
            
            
        
    
    
        
    
root1 = Node(25)
insert_node_iter(root1,3)
insert_node_iter(root1,7)
insert_node_iter(root1,2)
insert_node_iter(root1,30)
level_order_traversal(root1)
print("\n")
root2 = Node(25)
insert_node_iter(root2,8)
insert_node_iter(root2,28)
insert_node_iter(root2,21)
insert_node_iter(root2,31)
insert_node_iter(root2,24)
insert_node_iter(root2,50)
level_order_traversal(root2)
print("\n")
#x = Convert_BST_Into_DLL(root1)

Merge_Two_BSTs_In_DLL(root1,root2)
