# %%
## Start Date: March 18th
import queue
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None
        
class Binary_Search_Tree():
    
    def __init__(self,root):
        self.root = Node(root)
        
        
    def insert_node(self,root,data):
        
        if root == None:
            root = Node(data)
        
        else:
            if data < root.data:
                root.LeftChild = self.insert_node(root.LeftChild,data)
            else:
                root.RightChild = self.insert_node(root.RightChild,data)
                
        return root
                    
    def level_order_traversal(self,root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
                
        
    
BST = Binary_Search_Tree(9) 
BST.insert_node(BST.root,7)
BST.insert_node(BST.root,17)
BST.insert_node(BST.root,20)
BST.insert_node(BST.root,2)
BST.insert_node(BST.root,8)
BST.insert_node(BST.root,1)
BST.level_order_traversal(BST.root)
# Out:
# 9
# 7 17
# 2 8 20
# 1

# %%
## Insert a node in binary search tree.(Recur)[Start-end: March 19th]

import queue
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None

        
        
def insert_node(root,data):
    
    if root == None:
        root = Node(data)

    else:
        if data < root.data:
            root.LeftChild = insert_node(root.LeftChild,data)
        elif data > root.data:
            root.RightChild = insert_node(root.RightChild,data)

    return root
                    
def level_order_traversal(root):
        
        q = queue.Queue()
        q.put(root)
        q.put(None)
        
        while q.qsize() > 1:
            
            temp = q.get()
            if temp != None:
                print(temp.data,end= " ")
                if temp.LeftChild:
                    q.put(temp.LeftChild)

                if temp.RightChild:
                    q.put(temp.RightChild)
            else:
                q.put(None)
                print(end='\n')
                
def InOrder_Traversal(root):
    
    if root == None:
        return
    
    InOrder_Traversal(root.LeftChild)
    print(root.data,end=" ")
    InOrder_Traversal(root.RightChild)
    
    
    
def PreOrder_Traversal(root):
    
    if root == None:
        return
    print(root.data,end=" ")
    PreOrder_Traversal(root.LeftChild)
    PreOrder_Traversal(root.RightChild)
                
def PostOrder_Traversal(root):
    
    if root == None:
        return
    
    l = PostOrder_Traversal(root.LeftChild)
    r = PostOrder_Traversal(root.RightChild)
    print(root.data,end=" ")

        
        
    
    
root = Node(9)
insert_node(root,7)
insert_node(root,17)
insert_node(root,20)
insert_node(root,2)
insert_node(root,8)
insert_node(root,1)
#level_order_traversal(root)
#print("\n")
print("Inorder:")
InOrder_Traversal(root)
print("\n")
print("PreOrder")
PreOrder_Traversal(root)
print("\n")
print("PostOrder")
PostOrder_Traversal(root)
# Out:
# Inorder:
# 1 2 7 8 9 17 20
#
# PreOrder
# 9 7 2 1 8 17 20
#
# PostOrder
# 1 2 8 7 20 17 9

# %%
## Insert a node in binary search tree.(Iter)[Start-end: March 19th]
## Search a node in binary search tree(recur)[Start-end: March 19th]
## Search a node in binary search tree(Iter)[Start-end: March 20th]

import queue
class Node:
    def __init__(self,data):
        
        self.data = data
        self.LeftChild = None
        self.RightChild = None

        
        
def insert_node_iter(root,data):
    
    if root == None:
        root = Node(data)
        return root
        
    curr = root
    parent = None
    while curr != None:
        
        parent = curr
        if data < curr.data:
            curr = curr.LeftChild
            
        elif data > curr.data:
            curr = curr.RightChild
            
    if data < parent.data:
        parent.LeftChild = Node(data)
    elif data > parent.data:
        parent.RightChild = Node(data)
        
    return root

def search_node_recur(root,key):
    
    if root == None:
        return None
    
    if root.data == key:
        return True
    
    if key < root.data:
         return search_node_recur(root.LeftChild,key)
        
    elif key > root.data:
        return search_node_recur(root.RightChild,key)
        
    
def search_node_iter(root,key):
    
    if root == None:
        return None 
    
    curr = root
    Found = False
    
    while curr != None:
        
        if curr.data == key:
            Found = True
            break
        
        else:
            if key <= curr.data:
                curr = curr.LeftChild
                
            else:
                curr = curr.RightChild
    return Found
    
        
        
root = Node(9)
insert_node_iter(root,7)
insert_node_iter(root,17)
insert_node_iter(root,20)
insert_node_iter(root,2)
insert_node_iter(root,8)
insert_node_iter(root,1)
print("Inorder:")
InOrder_Traversal(root)
print("\n")
#x = search_node_recur(root,200)
x = search_node_iter(root,17)

if x == True:
    print("Node Found..")
    
else:
    print("Node not Found....")
# Out:
# Inorder:
# 1 2 7 8 9 17 20
#
# Node Found..
